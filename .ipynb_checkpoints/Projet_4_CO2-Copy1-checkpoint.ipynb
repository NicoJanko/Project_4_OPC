# %% [markdown]
# # Modelisation de la consommation totale d'energie

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
import sklearn.preprocessing as sk_prepro
from sklearn import metrics

# %%
df = pd.read_csv('data_full.csv')

# %%
data_num = df
target_tag ='GHGEmissionsIntensity'
target = data_num[target_tag]
sqf = data_num['PropertyGFABuilding(s)']
data_num = data_num.drop(labels = [target_tag,'SiteEnergyUse(kBtu)', 'ENERGYSTARScore','SiteEUI(kBtu/sf)', 'TotalGHGEmissions'], axis = 1)

col_name_lib = {}
col_name = data_num.columns
for i,v in enumerate(col_name):
    col_name_lib[f'{i}'] = v

# %%
data_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1630 entries, 0 to 1629
# Columns: 522 entries, BuildingType_Campus to ThirdLargestPropertyUseTypeGFA
# dtypes: float64(522)
# memory usage: 6.5 MB

# %% [markdown]
# ## Modèle linéaire

# %%
from sklearn.linear_model import Ridge
from sklearn import svm
from sklearn.neighbors import KNeighborsRegressor

# %%
from sklearn import linear_model
line_reg = linear_model.LinearRegression()

# %%
#first let's test this on knregressoe
xtrain, xtest, ytrain, ytest, sqftrain, sqftest = train_test_split(data_num, target, sqf, test_size = 0.2)

df_res = xtest
df_res_train = xtrain
#let's standard scale

sscaler = sk_prepro.StandardScaler()
sscaler_fit = sscaler.fit(xtrain)
xtrain = sscaler_fit.transform(xtrain)
xtest = sscaler_fit.transform(xtest)
#log scale the target
ytrain = np.log(ytrain)
ytest = np.log(ytest)

sqftrain = np.array(sqftrain).reshape(-1,1)
sqftest = np.array(sqftest).reshape(-1,1)

# %%
def true_pred_plot(y_train,pred_train, y_test, pred_test,figname):
    fig, ax = plt.subplots(2, figsize = (10,10))
    
    y_train= np.array(np.exp(y_train)).reshape(-1,1)
    pred_train = np.array(np.exp(pred_train)).reshape(-1,1)
    y_test = np.array(np.exp(y_test)).reshape(-1,1)
    pred_test = np.array(np.exp(pred_test)).reshape(-1,1)
    
    
    
    y_train = (y_train/1000)*sqftrain

    
    pred_train = (pred_train/1000)*sqftrain
    index = np.where(pred_train == np.inf)
    if index != 0:
        pred_train = pred_train[pred_train != np.inf].reshape(-1,1)
        y_train = np.delete(y_train, index)

    
    y_test = (y_test/1000)*sqftest

    
    pred_test = (pred_test/1000)*sqftest
    index = np.where(pred_test == np.inf)
    if index != 0:
        pred_test = pred_test[pred_test != np.inf].reshape(-1,1)
        y_test = np.delete(y_test, index)
        
    

    
    line_reg_train = line_reg.fit(pred_train,y_train)
    r2_train = line_reg_train.score(pred_train,y_train)
    rmse_train = (np.sqrt(metrics.mean_squared_error(y_train, pred_train))/np.mean(y_train))
    a = float(line_reg_train.coef_)
    b= line_reg_train.intercept_
    ax[0].scatter( y_train, pred_train)
    ax[0].plot([a*np.abs(b)+b, a*y_train.max()+b],[np.abs(b), ytrain.max()], linestyle = 'dashed')
    ax[0].text(0.7,0.4,'R2 : {:.3f} NRMSE : {: .2f}'.format(r2_train,rmse_train), transform = ax[0].transAxes)
    ax[0].set_xlabel('True values')
    ax[0].set_ylabel('Predicted values')
    ax[0].set_xlim(y_train.min(),y_train.max())
    ax[0].set_ylim(pred_train.min(),pred_train.max())
    ax[0].set_title('On train values')


    
    line_reg_test  = line_reg.fit(pred_test,y_test)
    r2_test =  line_reg_test.score(pred_test,y_test)
    rmse_test = (np.sqrt(metrics.mean_squared_error(y_test, pred_test))/np.mean(y_test))
    a = float(line_reg_test.coef_)
    b=  line_reg_test.intercept_
    ax[1].scatter( y_test, pred_test)
    ax[1].plot([a*np.abs(b)+b, a*y_test.max()+b],[np.abs(b), y_test.max()], linestyle = 'dashed')
    ax[1].text(0.7,0.4,'R2 : {:.3f} NRMSE : {: .2f}'.format(r2_test, rmse_test), transform = ax[1].transAxes)
    ax[1].set_xlabel('True values')
    ax[1].set_ylabel('Predicted values')
    ax[1].set_xlim(y_test.min(),y_test.max())
    ax[1].set_ylim(pred_test.min(),pred_test.max())
    ax[1].set_title('On test values')
    
    plt.show()
    plt.savefig(figname, bbox_inches = 'tight')
    plt.clf()

# %%
x = input('Do you want to launch ? [y/n]')
if x == 'y':

    line_reg_m = linear_model.LinearRegression()

    model_lr = line_reg_m.fit(xtrain,ytrain)


    true_pred_plot(ytrain,  model_lr.predict(xtrain), ytest,  model_lr.predict(xtest),'line_reg_co2.png')
# Out:
# Do you want to launch ? [y/n] y
# E:\temp\ipykernel_4512\2932118983.py:7: RuntimeWarning: overflow encountered in exp
#   pred_test = np.array(np.exp(pred_test)).reshape(-1,1)

# %%
#let's grid search for the k

k_grid = {'n_neighbors' : list(range(2,16))}
score = 'r2'

reg = GridSearchCV(KNeighborsRegressor(), k_grid, cv =3, scoring = score, verbose = 1)

reg.fit(xtrain, ytrain)

print('Best params on training set : {}'.format(reg.best_params_))

print('GridCV results : ')
for mean, std, k in zip(reg.cv_results_['mean_test_score'],
                       reg.cv_results_['std_test_score'],
                       reg.cv_results_['params']):
    print('{} = {:.3f} (+/- {:.3f}) for {}'.format(score,mean,std*2,k))
    
model_kn = KNeighborsRegressor(n_neighbors = reg.best_params_['n_neighbors']).fit(xtrain, ytrain)

true_pred_plot(ytrain, model_kn.predict(xtrain), ytest, model_kn.predict(xtest),'knn_co2.png')
# Out:
# Fitting 3 folds for each of 14 candidates, totalling 42 fits
# Best params on training set : {'n_neighbors': 7}
# GridCV results :
# r2 = -0.019 (+/- 0.166) for {'n_neighbors': 2}
# r2 = 0.045 (+/- 0.115) for {'n_neighbors': 3}
# r2 = 0.096 (+/- 0.079) for {'n_neighbors': 4}
# r2 = 0.128 (+/- 0.070) for {'n_neighbors': 5}
# r2 = 0.138 (+/- 0.073) for {'n_neighbors': 6}
# r2 = 0.148 (+/- 0.079) for {'n_neighbors': 7}
# r2 = 0.143 (+/- 0.077) for {'n_neighbors': 8}
# r2 = 0.138 (+/- 0.082) for {'n_neighbors': 9}
# r2 = 0.136 (+/- 0.073) for {'n_neighbors': 10}
# r2 = 0.134 (+/- 0.067) for {'n_neighbors': 11}
# r2 = 0.134 (+/- 0.061) for {'n_neighbors': 12}
# r2 = 0.131 (+/- 0.063) for {'n_neighbors': 13}
# r2 = 0.126 (+/- 0.066) for {'n_neighbors': 14}
# r2 = 0.122 (+/- 0.055) for {'n_neighbors': 15}

# %%
x = input('Do you want to launch ? [y/n]')
if x == 'y':

    #let's try with a svr
    C_range = [1.0, 5.0, 10.0, 100.0]
    kernels = ['linear', 'rbf', 'sigmoid', 'poly']
    degrees = [2,3,4]
    gamma_range  = np.logspace(-2, 1, 10)
    param_grid = {'gamma' : gamma_range, 'kernel' : kernels, 'degree' : degrees}

    score = 'neg_mean_squared_error'

    svr_cv = GridSearchCV(svm.SVR(), param_grid, cv = 3, scoring = score, verbose = 1)

    svr_cv.fit(xtrain, ytrain)

    print('Best params on training set : {}'.format(svr_cv.best_params_))
bkernel = svr_cv.best_params_['kernel']
bgamma = svr_cv.best_params_['gamma']
bdegree = svr_cv.best_params_['degree']
    
svr = svm.SVR(kernel=bkernel, C=1.0, gamma = bgamma, degree = bdegree)
model_svr = svr.fit(xtrain,ytrain)

true_pred_plot(ytrain, model_svr.predict(xtrain), ytest, model_svr.predict(xtest))
# Out:
# Do you want to launch ? [y/n] y
# Fitting 3 folds for each of 120 candidates, totalling 360 fits

# %%
from sklearn import kernel_ridge
#let's try with a ridge regression

x = input('Do you want to launch ? [y/n]')
if x == 'y':
    alpha_range = [1.0, 5.0, 10.0, 100.0]
    kernels = ['poly', 'rbf']
    degrees = [3,4,5]
    gamma_range  = np.logspace(-2, 1, 10)


    param_grid = {'gamma' : gamma_range, 'kernel' : kernels, 'degree' : degrees, 'alpha' : alpha_range}
    
    score = 'neg_mean_absolute_percentage_error'

    kernel_ridge_cv = GridSearchCV(kernel_ridge.KernelRidge(), param_grid, cv = 3, scoring = score, verbose = 1)

    kernel_ridge_cv.fit(xtrain, ytrain)

    print('Best params on training set : {}'.format(kernel_ridge_cv.best_params_))
    
bkernel = kernel_ridge_cv.best_params_['kernel']
bgamma = kernel_ridge_cv.best_params_['gamma']
bdegree = kernel_ridge_cv.best_params_['degree']
balpha = kernel_ridge_cv.best_params_['alpha']

model = kernel_ridge.KernelRidge(alpha = balpha, kernel = bkernel, degree = bdegree, gamma = bgamma)
model_kr = model.fit(xtrain, ytrain)

true_pred_plot(ytrain, model_kr.predict(xtrain), ytest, model_kr.predict(xtest))
# Out:
# Do you want to launch ? [y/n] y
# Fitting 3 folds for each of 360 candidates, totalling 1080 fits
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=6.12311e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.69085e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.28913e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.35028e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.13563e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.23868e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.08978e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.21815e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.06917e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.20935e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.51835e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.63652e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.14057e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.24484e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.08989e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.21828e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.06917e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.20935e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.80556e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.99455e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.14674e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.25255e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.09002e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.21845e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.06917e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.20935e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=9.04688e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=8.43324e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.25784e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.39137e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.09242e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.22144e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.06922e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.20942e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Best params on training set : {'alpha': 100.0, 'degree': 3, 'gamma': 10.0, 'kernel': 'rbf'}
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %% [markdown]
# ## Neural network

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
#test with a single perceptron
model1 = keras.Sequential()
model1.add(keras.Input(shape = xtrain.shape[1]))
model1.add(layers.Dense(1,input_dim = 2, activation = 'linear'))

model1.compile(metrics = [tf.keras.metrics.RootMeanSquaredError()], loss = 'mean_absolute_percentage_error', optimizer = 'adam')

model1.summary()

history = model1.fit(xtrain, ytrain, epochs = 50, batch_size = 1, verbose = 1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 523
#
# =================================================================
# Total params: 523
# Trainable params: 523
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1304/1304 [==============================] - 2s 1ms/step - loss: 5301911.5000 - root_mean_squared_error: 1.8000
# Epoch 2/50
# 1304/1304 [==============================] - 1s 975us/step - loss: 2779539.2500 - root_mean_squared_error: 1.8016
# Epoch 3/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 1683524.7500 - root_mean_squared_error: 1.8383
# Epoch 4/50
# 1304/1304 [==============================] - 1s 970us/step - loss: 2757881.2500 - root_mean_squared_error: 1.8430
# Epoch 5/50
# 1304/1304 [==============================] - 1s 913us/step - loss: 2533037.5000 - root_mean_squared_error: 1.8325
# Epoch 6/50
# 1304/1304 [==============================] - 1s 920us/step - loss: 3107763.2500 - root_mean_squared_error: 1.8183
# Epoch 7/50
# 1304/1304 [==============================] - 1s 915us/step - loss: 1829347.8750 - root_mean_squared_error: 1.8237
# Epoch 8/50
# 1304/1304 [==============================] - 1s 924us/step - loss: 3286481.7500 - root_mean_squared_error: 1.8088
# Epoch 9/50
# 1304/1304 [==============================] - 1s 925us/step - loss: 1530119.5000 - root_mean_squared_error: 1.7806
# Epoch 10/50
# 1304/1304 [==============================] - 1s 914us/step - loss: 3001919.5000 - root_mean_squared_error: 1.9640
# Epoch 11/50
# 1304/1304 [==============================] - 1s 959us/step - loss: 1768705.3750 - root_mean_squared_error: 1.8489
# Epoch 12/50
# 1304/1304 [==============================] - 1s 921us/step - loss: 3426080.5000 - root_mean_squared_error: 1.8891
# Epoch 13/50
# 1304/1304 [==============================] - 1s 916us/step - loss: 1797465.1250 - root_mean_squared_error: 1.8050
# Epoch 14/50
# 1304/1304 [==============================] - 1s 945us/step - loss: 3027459.2500 - root_mean_squared_error: 1.8627
# Epoch 15/50
# 1304/1304 [==============================] - 1s 942us/step - loss: 2230722.2500 - root_mean_squared_error: 1.7849
# Epoch 16/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 3032242.7500 - root_mean_squared_error: 1.8356
# Epoch 17/50
# 1304/1304 [==============================] - 1s 988us/step - loss: 1967143.1250 - root_mean_squared_error: 1.8269
# Epoch 18/50
# 1304/1304 [==============================] - 1s 919us/step - loss: 3224150.5000 - root_mean_squared_error: 1.9042
# Epoch 19/50
# 1304/1304 [==============================] - 1s 916us/step - loss: 1832898.1250 - root_mean_squared_error: 1.8022
# Epoch 20/50
# 1304/1304 [==============================] - 1s 937us/step - loss: 3097401.2500 - root_mean_squared_error: 1.8182
# Epoch 21/50
# 1304/1304 [==============================] - 1s 907us/step - loss: 2264893.2500 - root_mean_squared_error: 1.8026
# Epoch 22/50
# 1304/1304 [==============================] - 1s 944us/step - loss: 3036745.5000 - root_mean_squared_error: 1.9000
# Epoch 23/50
# 1304/1304 [==============================] - 1s 922us/step - loss: 2012842.0000 - root_mean_squared_error: 1.8093
# Epoch 24/50
# 1304/1304 [==============================] - 1s 908us/step - loss: 3010893.5000 - root_mean_squared_error: 1.7878
# Epoch 25/50
# 1304/1304 [==============================] - 1s 904us/step - loss: 1744664.3750 - root_mean_squared_error: 1.8080
# Epoch 26/50
# 1304/1304 [==============================] - 1s 903us/step - loss: 3720670.2500 - root_mean_squared_error: 1.8088
# Epoch 27/50
# 1304/1304 [==============================] - 1s 912us/step - loss: 2423843.0000 - root_mean_squared_error: 1.7851
# Epoch 28/50
# 1304/1304 [==============================] - 1s 932us/step - loss: 2477274.0000 - root_mean_squared_error: 1.7985
# Epoch 29/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 2436093.7500 - root_mean_squared_error: 1.8007
# Epoch 30/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 2724791.2500 - root_mean_squared_error: 1.7974
# Epoch 31/50
# 1304/1304 [==============================] - 1s 977us/step - loss: 2020617.0000 - root_mean_squared_error: 1.8381
# Epoch 32/50
# 1304/1304 [==============================] - 1s 930us/step - loss: 3366614.7500 - root_mean_squared_error: 1.7662
# Epoch 33/50
# 1304/1304 [==============================] - 1s 897us/step - loss: 1650863.3750 - root_mean_squared_error: 1.8097
# Epoch 34/50
# 1304/1304 [==============================] - 1s 958us/step - loss: 3588691.7500 - root_mean_squared_error: 1.7969
# Epoch 35/50
# 1304/1304 [==============================] - 1s 939us/step - loss: 1721725.5000 - root_mean_squared_error: 1.7939
# Epoch 36/50
# 1304/1304 [==============================] - 1s 922us/step - loss: 3211775.5000 - root_mean_squared_error: 1.8722
# Epoch 37/50
# 1304/1304 [==============================] - 1s 918us/step - loss: 1525515.5000 - root_mean_squared_error: 1.7990
# Epoch 38/50
# 1304/1304 [==============================] - 1s 946us/step - loss: 3483926.7500 - root_mean_squared_error: 1.8182
# Epoch 39/50
# 1304/1304 [==============================] - 1s 916us/step - loss: 2098097.7500 - root_mean_squared_error: 1.8190
# Epoch 40/50
# 1304/1304 [==============================] - 1s 923us/step - loss: 3169698.0000 - root_mean_squared_error: 1.8551
# Epoch 41/50
# 1304/1304 [==============================] - 1s 919us/step - loss: 2286309.0000 - root_mean_squared_error: 1.8308
# Epoch 42/50
# 1304/1304 [==============================] - 1s 999us/step - loss: 2754286.2500 - root_mean_squared_error: 1.7934
# Epoch 43/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 1957934.1250 - root_mean_squared_error: 1.8711
# Epoch 44/50
# 1304/1304 [==============================] - 1s 916us/step - loss: 2895380.2500 - root_mean_squared_error: 1.7954
# Epoch 45/50
# 1304/1304 [==============================] - 1s 915us/step - loss: 2030315.7500 - root_mean_squared_error: 1.8133
# Epoch 46/50
# 1304/1304 [==============================] - 1s 938us/step - loss: 2155460.0000 - root_mean_squared_error: 1.7985
# Epoch 47/50
# 1304/1304 [==============================] - 1s 966us/step - loss: 2846903.0000 - root_mean_squared_error: 1.8143
# Epoch 48/50
# 1304/1304 [==============================] - 1s 992us/step - loss: 3273258.5000 - root_mean_squared_error: 1.8084
# Epoch 49/50
# 1304/1304 [==============================] - 1s 943us/step - loss: 1917031.8750 - root_mean_squared_error: 1.8178
# Epoch 50/50
# 1304/1304 [==============================] - 1s 959us/step - loss: 2931208.7500 - root_mean_squared_error: 1.7725

# %%
true_pred_plot(ytrain, model1.predict(xtrain), ytest, model1.predict(xtest))
# Out:
# 41/41 [==============================] - 0s 851us/step
# 11/11 [==============================] - 0s 900us/step
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
model2 = keras.Sequential(
    [
        layers.Dense(xtrain.shape[1], activation="relu", name="layer1", input_shape=(xtrain.shape[1],), input_dim = 2),
        layers.Dense(287, activation="relu", name="layer2"),
        layers.Dense(1, activation = 'linear', name="layer3"),
    ]
)

model2.compile(metrics = [tf.keras.metrics.RootMeanSquaredError()], loss = 'mean_absolute_percentage_error', optimizer = 'adam')

model2.summary()

history2 = model2.fit(xtrain, ytrain, epochs = 50, batch_size = 1, verbose = 1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 522)               273006
#
#  layer2 (Dense)              (None, 287)               150101
#
#  layer3 (Dense)              (None, 1)                 288
#
# =================================================================
# Total params: 423,395
# Trainable params: 423,395
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1304/1304 [==============================] - 4s 2ms/step - loss: 3119965.7500 - root_mean_squared_error: 1.4804
# Epoch 2/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 9703442.0000 - root_mean_squared_error: 3.0423
# Epoch 3/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 43535652.0000 - root_mean_squared_error: 3.6327
# Epoch 4/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 17062496.0000 - root_mean_squared_error: 2.6747
# Epoch 5/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 23057438.0000 - root_mean_squared_error: 2.1116
# Epoch 6/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 21795292.0000 - root_mean_squared_error: 2.2240
# Epoch 7/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 9443478.0000 - root_mean_squared_error: 2.0220
# Epoch 8/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 15907505.0000 - root_mean_squared_error: 1.9843
# Epoch 9/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 20567930.0000 - root_mean_squared_error: 3.3499
# Epoch 10/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 18200944.0000 - root_mean_squared_error: 3.1030
# Epoch 11/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 4344359.0000 - root_mean_squared_error: 2.5034
# Epoch 12/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 6843466.0000 - root_mean_squared_error: 3.2692
# Epoch 13/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 5065534.5000 - root_mean_squared_error: 2.5365
# Epoch 14/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 4095097.0000 - root_mean_squared_error: 2.7876
# Epoch 15/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 5214218.0000 - root_mean_squared_error: 2.5668
# Epoch 16/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 3176775.7500 - root_mean_squared_error: 2.0884
# Epoch 17/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 4759134.0000 - root_mean_squared_error: 1.9203
# Epoch 18/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 7995388.0000 - root_mean_squared_error: 1.7143
# Epoch 19/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 2955793.0000 - root_mean_squared_error: 1.7206
# Epoch 20/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 8160717.5000 - root_mean_squared_error: 1.8573
# Epoch 21/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 3980919.7500 - root_mean_squared_error: 1.8316
# Epoch 22/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 2765223.7500 - root_mean_squared_error: 1.4568
# Epoch 23/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 2759159.2500 - root_mean_squared_error: 1.4221
# Epoch 24/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 4325045.0000 - root_mean_squared_error: 2.2538
# Epoch 25/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 6240256.5000 - root_mean_squared_error: 2.1775
# Epoch 26/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 2543710.2500 - root_mean_squared_error: 2.7886
# Epoch 27/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 4578839.5000 - root_mean_squared_error: 2.3915
# Epoch 28/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 2390822.0000 - root_mean_squared_error: 1.7615
# Epoch 29/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 2442718.5000 - root_mean_squared_error: 1.7701
# Epoch 30/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 4916972.5000 - root_mean_squared_error: 2.3376
# Epoch 31/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 1520433.1250 - root_mean_squared_error: 4.8552
# Epoch 32/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 9775254.0000 - root_mean_squared_error: 4.6849
# Epoch 33/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 16067311.0000 - root_mean_squared_error: 3.0132
# Epoch 34/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 8493257.0000 - root_mean_squared_error: 5.2094
# Epoch 35/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 5109214.0000 - root_mean_squared_error: 5.8433
# Epoch 36/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 5595090.0000 - root_mean_squared_error: 4.5018
# Epoch 37/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 6102876.0000 - root_mean_squared_error: 6.4694
# Epoch 38/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 5873995.5000 - root_mean_squared_error: 10.0897
# Epoch 39/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 22390516.0000 - root_mean_squared_error: 8.6727
# Epoch 40/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 9284431.0000 - root_mean_squared_error: 6.7296
# Epoch 41/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 6774252.5000 - root_mean_squared_error: 8.7969
# Epoch 42/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 15977081.0000 - root_mean_squared_error: 10.0317
# Epoch 43/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 17260576.0000 - root_mean_squared_error: 8.7952
# Epoch 44/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 13650003.0000 - root_mean_squared_error: 3.7142
# Epoch 45/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 7819521.5000 - root_mean_squared_error: 3.2049
# Epoch 46/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 28653258.0000 - root_mean_squared_error: 2.0572
# Epoch 47/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 4432360.0000 - root_mean_squared_error: 3.4097
# Epoch 48/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 7469104.0000 - root_mean_squared_error: 3.1255
# Epoch 49/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 6014805.0000 - root_mean_squared_error: 2.0806
# Epoch 50/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 1736478.3750 - root_mean_squared_error: 2.3293

# %%
true_pred_plot(ytrain, model2.predict(xtrain), ytest, model2.predict(xtest))
# Out:
# 41/41 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
#now with a multi layer network

model3 = keras.Sequential(
    [
        layers.Dense(xtrain.shape[1], activation="relu", name="layer1", input_shape=(xtrain.shape[1],), input_dim = 2),
        layers.Dense(287, activation="relu", name="layer2b"),
        layers.Dense(82, activation="relu", name="layer3"),
        layers.Dense(20, activation="relu", name="layer4"),
        layers.Dense(4, activation = "relu", name = "layer5"),
        layers.Dense(1, activation = 'relu', name="layer6"),
    ]
)

model3.compile(metrics = [tf.keras.metrics.RootMeanSquaredError()], loss = 'mean_absolute_percentage_error', optimizer = 'adam')

model3.summary()

history3 = model3.fit(xtrain, ytrain, epochs = 50, batch_size = 1, verbose = 1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 522)               273006
#
#  layer2b (Dense)             (None, 287)               150101
#
#  layer3 (Dense)              (None, 82)                23616
#
#  layer4 (Dense)              (None, 20)                1660
#
#  layer5 (Dense)              (None, 4)                 84
#
#  layer6 (Dense)              (None, 1)                 5
#
# =================================================================
# Total params: 448,472
# Trainable params: 448,472
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1304/1304 [==============================] - 5s 3ms/step - loss: 99.7264 - root_mean_squared_error: 1.1989
# Epoch 2/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 3/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 4/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 5/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 6/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 7/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 8/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 9/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 10/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 11/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 12/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 13/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 14/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 15/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 16/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 17/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 18/50
# 1304/1304 [==============================] - 5s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 19/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 20/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 21/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 22/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 23/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 24/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 25/50
# 1304/1304 [==============================] - 5s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 26/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 27/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 28/50
# 1304/1304 [==============================] - 5s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 29/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 30/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 31/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 32/50
# 1304/1304 [==============================] - 5s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 33/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 34/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 35/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 36/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 37/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 38/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 39/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 40/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 41/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 42/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 43/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 44/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 45/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 46/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 47/50
# 1304/1304 [==============================] - 5s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 48/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 49/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965
# Epoch 50/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 99.5399 - root_mean_squared_error: 1.1965

# %%
true_pred_plot(ytrain, model3.predict(xtrain), ytest, model3.predict(xtest))
# Out:
# 41/41 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
from sklearn.ensemble import RandomForestRegressor

n_grid = {'n_estimators' : list(np.arange(750,1250,50))}
score = 'r2'

rfr_grid = GridSearchCV(RandomForestRegressor(), n_grid, cv =3, scoring = score, verbose = 2)

rfr_grid.fit(xtrain, ytrain)

print('Best params on training set : {}'.format(rfr_grid.best_params_))

    
model_rfr = RandomForestRegressor(n_estimators=rfr_grid.best_params_['n_estimators'], verbose = 1).fit(xtrain, ytrain)

true_pred_plot(ytrain, model_rfr.predict(xtrain), ytest, model_rfr.predict(xtest))
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] END ...................................n_estimators=750; total time=  10.4s
# [CV] END ...................................n_estimators=750; total time=  10.9s
# [CV] END ...................................n_estimators=750; total time=  10.7s
# [CV] END ...................................n_estimators=800; total time=  11.1s
# [CV] END ...................................n_estimators=800; total time=  11.4s
# [CV] END ...................................n_estimators=800; total time=  11.5s
# [CV] END ...................................n_estimators=850; total time=  11.7s
# [CV] END ...................................n_estimators=850; total time=  12.1s
# [CV] END ...................................n_estimators=850; total time=  12.1s
# [CV] END ...................................n_estimators=900; total time=  12.4s
# [CV] END ...................................n_estimators=900; total time=  12.7s
# [CV] END ...................................n_estimators=900; total time=  13.1s
# [CV] END ...................................n_estimators=950; total time=  13.5s
# [CV] END ...................................n_estimators=950; total time=  13.7s
# [CV] END ...................................n_estimators=950; total time=  13.7s
# [CV] END ..................................n_estimators=1000; total time=  13.9s
# [CV] END ..................................n_estimators=1000; total time=  14.1s
# [CV] END ..................................n_estimators=1000; total time=  14.2s
# [CV] END ..................................n_estimators=1050; total time=  14.4s
# [CV] END ..................................n_estimators=1050; total time=  14.7s
# [CV] END ..................................n_estimators=1050; total time=  15.0s
# [CV] END ..................................n_estimators=1100; total time=  15.2s
# [CV] END ..................................n_estimators=1100; total time=  15.4s
# [CV] END ..................................n_estimators=1100; total time=  15.5s
# [CV] END ..................................n_estimators=1150; total time=  15.7s
# [CV] END ..................................n_estimators=1150; total time=  16.0s
# [CV] END ..................................n_estimators=1150; total time=  16.4s
# [CV] END ..................................n_estimators=1200; total time=  16.6s
# [CV] END ..................................n_estimators=1200; total time=  16.8s
# [CV] END ..................................n_estimators=1200; total time=  17.1s
# Best params on training set : {'n_estimators': 1100}
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1100 out of 1100 | elapsed:   23.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1100 out of 1100 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1100 out of 1100 | elapsed:    0.0s finished
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
from sklearn.ensemble import GradientBoostingRegressor

n_grid = {'n_estimators' : list(np.arange(250,750,50))}
score = 'r2'

xgb_grid = GridSearchCV( GradientBoostingRegressor(), n_grid, cv =3, scoring = score, verbose = 2)

xgb_grid.fit(xtrain, ytrain)

print('Best params on training set : {}'.format(xgb_grid.best_params_))

    
model_xgb =  GradientBoostingRegressor(n_estimators=xgb_grid.best_params_['n_estimators'], verbose = 1).fit(xtrain, ytrain)

true_pred_plot(ytrain, model_xgb.predict(xtrain), ytest, model_xgb.predict(xtest))
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] END ...................................n_estimators=250; total time=   1.5s
# [CV] END ...................................n_estimators=250; total time=   1.4s
# [CV] END ...................................n_estimators=250; total time=   1.4s
# [CV] END ...................................n_estimators=300; total time=   1.8s
# [CV] END ...................................n_estimators=300; total time=   1.8s
# [CV] END ...................................n_estimators=300; total time=   1.8s
# [CV] END ...................................n_estimators=350; total time=   2.1s
# [CV] END ...................................n_estimators=350; total time=   2.1s
# [CV] END ...................................n_estimators=350; total time=   2.1s
# [CV] END ...................................n_estimators=400; total time=   2.5s
# [CV] END ...................................n_estimators=400; total time=   2.5s
# [CV] END ...................................n_estimators=400; total time=   2.6s
# [CV] END ...................................n_estimators=450; total time=   2.8s
# [CV] END ...................................n_estimators=450; total time=   2.9s
# [CV] END ...................................n_estimators=450; total time=   2.9s
# [CV] END ...................................n_estimators=500; total time=   3.1s
# [CV] END ...................................n_estimators=500; total time=   3.1s
# [CV] END ...................................n_estimators=500; total time=   3.0s
# [CV] END ...................................n_estimators=550; total time=   3.5s
# [CV] END ...................................n_estimators=550; total time=   3.4s
# [CV] END ...................................n_estimators=550; total time=   3.4s
# [CV] END ...................................n_estimators=600; total time=   4.0s
# [CV] END ...................................n_estimators=600; total time=   3.8s
# [CV] END ...................................n_estimators=600; total time=   3.8s
# [CV] END ...................................n_estimators=650; total time=   4.1s
# [CV] END ...................................n_estimators=650; total time=   4.1s
# [CV] END ...................................n_estimators=650; total time=   3.9s
# [CV] END ...................................n_estimators=700; total time=   4.4s
# [CV] END ...................................n_estimators=700; total time=   4.4s
# [CV] END ...................................n_estimators=700; total time=   4.5s
# Best params on training set : {'n_estimators': 250}
#       Iter       Train Loss   Remaining Time
#          1           1.3508            2.48s
#          2           1.2927            2.48s
#          3           1.2466            2.39s
#          4           1.2022            2.40s
#          5           1.1671            2.35s
#          6           1.1322            2.36s
#          7           1.1017            2.32s
#          8           1.0767            2.30s
#          9           1.0537            2.33s
#         10           1.0317            2.28s
#         20           0.8901            2.21s
#         30           0.8055            2.20s
#         40           0.7346            2.13s
#         50           0.6946            1.99s
#         60           0.6585            1.85s
#         70           0.6365            1.73s
#         80           0.6064            1.62s
#         90           0.5919            1.51s
#        100           0.5783            1.41s
#        200           0.4581            0.45s
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
def r2(pred,y):
    pred = np.array(np.exp(pred)).reshape(-1,1)
    y = np.array(np.exp(y)).reshape(-1,1)
    
    pred = (pred/1000)*sqftest
    y = (y/1000)*sqftest
    
    line_reg_test  = line_reg.fit(pred,y)
    r2_value =  line_reg_test.score(pred,y)
    return r2_value

def rmse(pred,y):
    pred = np.array(np.exp(pred)).reshape(-1,1)
    y = np.array(np.exp(y)).reshape(-1,1)
    
    pred = (pred/1000)*sqftest
    y = (y/1000)*sqftest
    
    rmse_value = np.sqrt(metrics.mean_squared_error(y,pred))
    return rmse_value

def nrmse(pred,y):
    pred = np.array(np.exp(pred)).reshape(-1,1)
    y = np.array(np.exp(y)).reshape(-1,1)
    
    pred = (pred/1000)*sqftest
    y = (y/1000)*sqftest
    
    nrmse_value = (np.sqrt(metrics.mean_squared_error(y,pred))/np.mean(y))
    return nrmse_value
                   
def mae(pred,y):
    pred = np.array(np.exp(pred)).reshape(-1,1)
    y = np.array(np.exp(y)).reshape(-1,1)
    
    pred = (pred/1000)*sqftest
    y = (y/1000)*sqftest
    
    mae_value = metrics.mean_absolute_error(y,pred)
    return mae_value

# %%
metrics_all = {}

models = [model_kn,svr,model_kr,model3,model_rfr,model_xgb]
r2l=[]
rmsel=[]
nrmsel=[]
mael=[]

for i in models:
    r2l.append(r2(i.predict(xtest),ytest))
    rmsel.append(rmse(i.predict(xtest), ytest))
    nrmsel.append(nrmse(i.predict(xtest), ytest))
    mael.append(mae(i.predict(xtest), ytest))
    
metrics_all['r2'] = r2l
metrics_all['rmse'] = rmsel
metrics_all['nrmse'] = nrmsel
metrics_all['mae'] = mael

model_names = ['KNN_Regressor', 'SVR', 'Kernel_Ridge_Regressor','Neural_Network', 'Random_Forest_Regressor', 'XGBoost']
df_metrics = pd.DataFrame(metrics_all, index = model_names)

fig = plt.figure(figsize=(20, 20))
for i in range(df_metrics.shape[1]):
    ax = fig.add_subplot(2,2, (i+1))
    b = ax.bar(x=df_metrics.index,height = df_metrics.iloc[:, i])
    ax.set_title(df_metrics.columns[i], fontsize=14)
    ax.tick_params(axis='x', labelrotation = 35)
    if i != 0:
        ax.set_yscale('log')
# Out:
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1100 out of 1100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1100 out of 1100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1100 out of 1100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1100 out of 1100 | elapsed:    0.0s finished

# %%
importance = model_rfr.feature_importances_
nul_col = []
for i,v in enumerate(importance):
    if v == 0:
        nul_col.append(i)
nul_col_name = []
for i in nul_col:
    nul_col_name.append(col_name_lib[str(i)])
print(len(nul_col_name))

df_fi = {}
for i,v in enumerate(importance):
    x = col_name_lib[str(i)]
    df_fi[f'{x}'] = v

df_fi = pd.DataFrame(df_fi, index = ['Feature_Importance']).T
print(df_fi['Feature_Importance'].nlargest(10))


# plot feature importance
fig, ax = plt.subplots(figsize = (20,20))
ax.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# 60
# ThirdLargestPropertyUseTypeGFA                          0.177678
# PropertyGFABuilding(s)                                  0.092357
# LargestPropertyUseType_Office                           0.061149
# YearBuilt                                               0.060770
# SecondLargestPropertyUseTypeGFA                         0.057639
# Latitude                                                0.057286
# Longitude                                               0.052650
# ListOfAllPropertyUseTypes_Non-Refrigerated Warehouse    0.034628
# LargestPropertyUseType_Non-Refrigerated Warehouse       0.026965
# ZipCode                                                 0.026383
# Name: Feature_Importance, dtype: float64

# %%
df_year={}
df_tar = pd.DataFrame(ytest)
df_res = df_res.join(df_tar)
for i in df_res['YearBuilt'].unique():
    df_year[f'{i}'] = df_res[df_res['YearBuilt'] == i]
len(df_year)
# Out:
# 100

# %%
def feature_error(df_lib,model):
    results = []
    for i in df_lib:
        x = df_lib[str(i)]
        y = x['GHGEmissionsIntensity']
        x = x.drop(axis = 1, labels = 'GHGEmissionsIntensity')
        sqf = x['PropertyGFABuilding(s)']
        x = sscaler_fit.transform(x)
        
        y = np.array(np.log(y)).reshape(-1,1)     
        pred = model.predict(x)
        
        y = np.array(np.exp(y)).reshape(-1,1)
        pred = np.array(np.exp(pred)).reshape(-1,1)
        
        sqf = np.array(sqf).reshape(-1,1)
        y = y*sqf
        pred = pred*sqf
        
        results.append((np.sqrt(metrics.mean_squared_error(y,pred))/np.mean(y)) )
    return results

# %%
results = feature_error(df_year,model_rfr)

results_year = {}
for i,v in zip(df_year,results):
    results_year[f'{i}'] = v
    
results_year = pd.DataFrame(results_year, index = ['NRMSE']).T
print(results_year['NRMSE'].nlargest(10))

fig, ax = plt.subplots(1,2,figsize = (30,15))
ax[0].bar([x for x in range(len(results_year.index))],results_year['NRMSE'])
ax[0].text(0.7,0.4,'mean : {:.3f} max : {: .2f}'.format(results_year['NRMSE'].mean(), results_year['NRMSE'].max()), transform = ax[0].transAxes)
ax[1].pie(df_res_train['YearBuilt'].value_counts(), labels = df_res_train['YearBuilt'].unique())
plt.show()
# Out:
# E:\Data_Science\Anaconda\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1100 out of 1100 | elapsed:    0.2s finished
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 results = feature_error(df_year,model_rfr)
#       3 results_year = {}
#       4 for i,v in zip(df_year,results):
#
# Input In [26], in feature_error(df_lib, model)
#      17     y = y*sqf
#      18     pred = pred*sqf
# ---> 20     results.append((np.sqrt(metrics.mean_squared_error(y,pred))/np.mean(y)) )
#      21 return results
#
# File E:\Data_Science\Anaconda\lib\site-packages\sklearn\metrics\_regression.py:438, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     378 def mean_squared_error(
#     379     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     380 ):
#     381     """Mean squared error regression loss.
#     382
#     383     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     436     0.825...
#     437     """
# --> 438     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     439         y_true, y_pred, multioutput
#     440     )
#     441     check_consistent_length(y_true, y_pred, sample_weight)
#     442     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File E:\Data_Science\Anaconda\lib\site-packages\sklearn\metrics\_regression.py:95, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      61 """Check that y_true and y_pred belong to the same regression task.
#      62
#      63 Parameters
#    (...)
#      92     the dtype argument passed to check_array.
#      93 """
#      94 check_consistent_length(y_true, y_pred)
# ---> 95 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#      98 if y_true.ndim == 1:
#
# File E:\Data_Science\Anaconda\lib\site-packages\sklearn\utils\validation.py:800, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     794         raise ValueError(
#     795             "Found array with dim %d. %s expected <= 2."
#     796             % (array.ndim, estimator_name)
#     797         )
#     799     if force_all_finite:
# --> 800         _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     802 if ensure_min_samples > 0:
#     803     n_samples = _num_samples(array)
#
# File E:\Data_Science\Anaconda\lib\site-packages\sklearn\utils\validation.py:114, in _assert_all_finite(X, allow_nan, msg_dtype)
#     107     if (
#     108         allow_nan
#     109         and np.isinf(X).any()
#     110         or not allow_nan
#     111         and not np.isfinite(X).all()
#     112     ):
#     113         type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114         raise ValueError(
#     115             msg_err.format(
#     116                 type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117             )
#     118         )
#     119 # for object dtype data, we only check for NaNs (GH-13254)
#     120 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
# ## Etude de l'impact de l'Energy Score

# %%
data_num = df
target_tag ='GHGEmissionsIntensity'
target = data_num[target_tag]
sqf = data_num['PropertyGFABuilding(s)']
data_num = data_num.drop(labels = [target_tag,'SiteEnergyUse(kBtu)', 'SiteEUI(kBtu/sf)', 'TotalGHGEmissions'], axis = 1)

col_name_lib = {}
col_name = data_num.columns
for i,v in enumerate(col_name):
    col_name_lib[f'{i}'] = v
    
#first let's test this on knregressoe
xtrain, xtest, ytrain, ytest, sqftrain, sqftest = train_test_split(data_num, target, sqf, test_size = 0.2)

df_res = xtest
df_res_train = xtrain
#let's standard scale

sscaler = sk_prepro.StandardScaler()
sscaler_fit2 = sscaler.fit(xtrain)
xtrain = sscaler_fit2.transform(xtrain)
xtest = sscaler_fit2.transform(xtest)
#log scale the target
ytrain = np.log(ytrain)
ytest = np.log(ytest)

sqftrain = np.array(sqftrain).reshape(-1,1)
sqftest = np.array(sqftest).reshape(-1,1)

# %%
k_grid = {'n_neighbors' : list(range(2,16))}
score = 'r2'

reg = GridSearchCV(KNeighborsRegressor(), k_grid, cv =3, scoring = score, verbose = 1)

reg.fit(xtrain, ytrain)

model_kn2 = KNeighborsRegressor(n_neighbors = reg.best_params_['n_neighbors']).fit(xtrain, ytrain)


#let's try with a svr
C_range = [1.0, 5.0, 10.0, 100.0]
kernels = ['linear', 'rbf', 'sigmoid', 'poly']
degrees = [2,3,4]
gamma_range  = np.logspace(-2, 1, 10)
param_grid = {'gamma' : gamma_range, 'kernel' : kernels, 'degree' : degrees}

score = 'neg_mean_squared_error'

svr_cv = GridSearchCV(svm.SVR(), param_grid, cv = 3, scoring = score, verbose = 1)

svr_cv.fit(xtrain, ytrain)


bkernel = svr_cv.best_params_['kernel']
bgamma = svr_cv.best_params_['gamma']
bdegree = svr_cv.best_params_['degree']
    
svr = svm.SVR(kernel=bkernel, C=1.0, gamma = bgamma, degree = bdegree)
model_svr2= svr.fit(xtrain,ytrain)

#kernel ridge
alpha_range = [1.0, 5.0, 10.0, 100.0]
kernels = ['poly', 'rbf']
degrees = [3,4,5]
gamma_range  = np.logspace(-2, 1, 10)


param_grid = {'gamma' : gamma_range, 'kernel' : kernels, 'degree' : degrees, 'alpha' : alpha_range}
    
score = 'neg_mean_absolute_percentage_error'

kernel_ridge_cv = GridSearchCV(kernel_ridge.KernelRidge(), param_grid, cv = 3, scoring = score, verbose = 1)

kernel_ridge_cv.fit(xtrain, ytrain)

bkernel = kernel_ridge_cv.best_params_['kernel']
bgamma = kernel_ridge_cv.best_params_['gamma']
bdegree = kernel_ridge_cv.best_params_['degree']
balpha = kernel_ridge_cv.best_params_['alpha']

model = kernel_ridge.KernelRidge(alpha = balpha, kernel = bkernel, degree = bdegree, gamma = bgamma)
model_kr2 = model.fit(xtrain, ytrain)

#Neural network
model3_2 = keras.Sequential(
    [
        layers.Dense(xtrain.shape[1], activation="relu", name="layer1", input_shape=(xtrain.shape[1],), input_dim = 2),
        layers.Dense(287, activation="relu", name="layer2b"),
        layers.Dense(82, activation="relu", name="layer3"),
        layers.Dense(20, activation="relu", name="layer4"),
        layers.Dense(4, activation = "relu", name = "layer5"),
        layers.Dense(1, activation = 'relu', name="layer6"),
    ]
)

model3_2.compile(metrics = [tf.keras.metrics.RootMeanSquaredError()], loss = 'mean_absolute_percentage_error', optimizer = 'adam')

model3_2.summary()

history3 = model3_2.fit(xtrain, ytrain, epochs = 50, batch_size = 1, verbose = 1)

#random forest
n_grid = {'n_estimators' : list(np.arange(750,1250,50))}
score = 'r2'

rfr_grid = GridSearchCV(RandomForestRegressor(), n_grid, cv =3, scoring = score, verbose = 2)

rfr_grid.fit(xtrain, ytrain)

print('Best params on training set : {}'.format(rfr_grid.best_params_))

    
model_rfr2 = RandomForestRegressor(n_estimators=rfr_grid.best_params_['n_estimators'], verbose = 1).fit(xtrain, ytrain)

#xgb
n_grid = {'n_estimators' : list(np.arange(250,750,50))}
score = 'r2'

xgb_grid = GridSearchCV( GradientBoostingRegressor(), n_grid, cv =3, scoring = score, verbose = 2)

xgb_grid.fit(xtrain, ytrain)

print('Best params on training set : {}'.format(xgb_grid.best_params_))

    
model_xgb2 =  GradientBoostingRegressor(n_estimators=xgb_grid.best_params_['n_estimators'], verbose = 1).fit(xtrain, ytrain)


#plot the metrics
metrics_all = {}

models = [model_kn2,model_svr2,model_kr2,model3_2,model_rfr2,model_xgb2]
r2l=[]
rmsel=[]
nrmsel=[]
mael=[]

for i in models:
    r2l.append(r2(i.predict(xtest),ytest))
    rmsel.append(rmse(i.predict(xtest), ytest))
    nrmsel.append(nrmse(i.predict(xtest), ytest))
    mael.append(mae(i.predict(xtest), ytest))
    
metrics_all['r2'] = r2l
metrics_all['rmse'] = rmsel
metrics_all['nrmse'] = nrmsel
metrics_all['mae'] = mael

model_names = ['KNN_Regressor', 'SVR', 'Kernel_Ridge_Regressor','Neural_Network', 'Random_Forest_Regressor', 'XGBoost']
df_metrics = pd.DataFrame(metrics_all, index = model_names)

fig = plt.figure(figsize=(20, 20))
for i in range(df_metrics.shape[1]):
    ax = fig.add_subplot(2,2, (i+1))
    b = ax.bar(x=df_metrics.index,height = df_metrics.iloc[:, i])
    ax.set_title(df_metrics.columns[i], fontsize=14)
    ax.tick_params(axis='x', labelrotation = 35)
    if i != 0:
        ax.set_yscale('log')
# Out:
# Fitting 3 folds for each of 14 candidates, totalling 42 fits
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# Fitting 3 folds for each of 240 candidates, totalling 720 fits
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 523)               274052
#
#  layer2b (Dense)             (None, 287)               150388
#
#  layer3 (Dense)              (None, 82)                23616
#
#  layer4 (Dense)              (None, 20)                1660
#
#  layer5 (Dense)              (None, 4)                 84
#
#  layer6 (Dense)              (None, 1)                 5
#
# =================================================================
# Total params: 449,805
# Trainable params: 449,805
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1304/1304 [==============================] - 4s 2ms/step - loss: 99.4175 - root_mean_squared_error: 1.1888
# Epoch 2/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 3/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 4/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 5/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 6/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 7/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 8/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 9/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 10/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 11/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 12/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 13/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 14/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 15/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 16/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 17/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 18/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 19/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 20/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 21/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 22/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 23/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 24/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 25/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 26/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 27/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 28/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 29/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 30/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 31/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 32/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 33/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 34/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 35/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 36/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 37/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 38/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 39/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 40/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 41/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 42/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 43/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 44/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 45/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 46/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 47/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 48/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 49/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Epoch 50/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 99.3865 - root_mean_squared_error: 1.1884
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] END ...................................n_estimators=750; total time=  10.8s
# [CV] END ...................................n_estimators=750; total time=  10.3s
# [CV] END ...................................n_estimators=750; total time=  10.2s
# [CV] END ...................................n_estimators=800; total time=  10.9s
# [CV] END ...................................n_estimators=800; total time=  10.8s
# [CV] END ...................................n_estimators=800; total time=  10.9s
# [CV] END ...................................n_estimators=850; total time=  11.6s
# [CV] END ...................................n_estimators=850; total time=  11.6s
# [CV] END ...................................n_estimators=850; total time=  11.6s
# [CV] END ...................................n_estimators=900; total time=  12.3s
# [CV] END ...................................n_estimators=900; total time=  12.3s
# [CV] END ...................................n_estimators=900; total time=  12.2s
# [CV] END ...................................n_estimators=950; total time=  12.9s
# [CV] END ...................................n_estimators=950; total time=  13.8s
# [CV] END ...................................n_estimators=950; total time=  14.0s
# [CV] END ..................................n_estimators=1000; total time=  14.7s
# [CV] END ..................................n_estimators=1000; total time=  14.0s
# [CV] END ..................................n_estimators=1000; total time=  13.9s
# [CV] END ..................................n_estimators=1050; total time=  14.7s
# [CV] END ..................................n_estimators=1050; total time=  14.7s
# [CV] END ..................................n_estimators=1050; total time=  14.7s
# [CV] END ..................................n_estimators=1100; total time=  15.7s
# [CV] END ..................................n_estimators=1100; total time=  15.4s
# [CV] END ..................................n_estimators=1100; total time=  15.6s
# [CV] END ..................................n_estimators=1150; total time=  16.2s
# [CV] END ..................................n_estimators=1150; total time=  16.6s
# [CV] END ..................................n_estimators=1150; total time=  16.1s
# [CV] END ..................................n_estimators=1200; total time=  18.1s
# [CV] END ..................................n_estimators=1200; total time=  17.0s
# [CV] END ..................................n_estimators=1200; total time=  16.2s
# Best params on training set : {'n_estimators': 1150}
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1150 out of 1150 | elapsed:   24.6s finished
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] END ...................................n_estimators=250; total time=   1.5s
# [CV] END ...................................n_estimators=250; total time=   1.6s
# [CV] END ...................................n_estimators=250; total time=   1.5s
# [CV] END ...................................n_estimators=300; total time=   1.8s
# [CV] END ...................................n_estimators=300; total time=   1.8s
# [CV] END ...................................n_estimators=300; total time=   1.8s
# [CV] END ...................................n_estimators=350; total time=   2.2s
# [CV] END ...................................n_estimators=350; total time=   2.2s
# [CV] END ...................................n_estimators=350; total time=   2.2s
# [CV] END ...................................n_estimators=400; total time=   2.5s
# [CV] END ...................................n_estimators=400; total time=   2.5s
# [CV] END ...................................n_estimators=400; total time=   2.5s
# [CV] END ...................................n_estimators=450; total time=   2.9s
# [CV] END ...................................n_estimators=450; total time=   2.9s
# [CV] END ...................................n_estimators=450; total time=   2.8s
# [CV] END ...................................n_estimators=500; total time=   3.1s
# [CV] END ...................................n_estimators=500; total time=   3.1s
# [CV] END ...................................n_estimators=500; total time=   3.1s
# [CV] END ...................................n_estimators=550; total time=   3.6s
# [CV] END ...................................n_estimators=550; total time=   3.5s
# [CV] END ...................................n_estimators=550; total time=   3.4s
# [CV] END ...................................n_estimators=600; total time=   3.7s
# [CV] END ...................................n_estimators=600; total time=   3.8s
# [CV] END ...................................n_estimators=600; total time=   3.7s
# [CV] END ...................................n_estimators=650; total time=   4.1s
# [CV] END ...................................n_estimators=650; total time=   4.1s
# [CV] END ...................................n_estimators=650; total time=   4.2s
# [CV] END ...................................n_estimators=700; total time=   4.6s
# [CV] END ...................................n_estimators=700; total time=   4.4s
# [CV] END ...................................n_estimators=700; total time=   4.4s
# Best params on training set : {'n_estimators': 250}
#       Iter       Train Loss   Remaining Time
#          1           1.3190            2.25s
#          2           1.2559            1.99s
#          3           1.2043            2.06s
#          4           1.1580            2.03s
#          5           1.1192            2.06s
#          6           1.0815            1.99s
#          7           1.0484            2.01s
#          8           1.0170            2.00s
#          9           0.9909            2.01s
#         10           0.9666            1.99s
#         20           0.8033            1.91s
#         30           0.7069            1.86s
#         40           0.6504            1.80s
#         50           0.6144            1.72s
#         60           0.5809            1.65s
#         70           0.5531            1.56s
#         80           0.5339            1.48s
#         90           0.5157            1.40s
#        100           0.4974            1.32s
#        200           0.3937            0.44s
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1150 out of 1150 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1150 out of 1150 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1150 out of 1150 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1150 out of 1150 | elapsed:    0.1s finished
