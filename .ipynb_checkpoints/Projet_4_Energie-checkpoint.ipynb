# %% [markdown]
# # Modelisation de la consommation totale d'energie

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
import sklearn.preprocessing as sk_prepro
from sklearn import metrics

# %%
df = pd.read_csv('data_full.csv')

# %%
data_num = df
target_tag = 'SiteEUI(kBtu/sf)'
target = data_num[target_tag]
label = ['TotalGHGEmissions', 'ENERGYSTARScore','SiteEnergyUse(kBtu)', 'GHGEmissionsIntensity']
sqf = data_num['PropertyGFABuilding(s)']
data_num = data_num.drop(labels = [target_tag, 'TotalGHGEmissions', 'ENERGYSTARScore','SiteEnergyUse(kBtu)', 'GHGEmissionsIntensity'], axis = 1)

# %%
data_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1630 entries, 0 to 1629
# Columns: 522 entries, 0 to ThirdLargestPropertyUseTypeGFA
# dtypes: float64(522)
# memory usage: 6.5 MB

# %% [markdown]
# ## Modèle linéaire

# %%
from sklearn.linear_model import Ridge
from sklearn import svm
from sklearn.neighbors import KNeighborsRegressor

# %%
#first let's test this on knregressoe
xtrain, xtest, ytrain, ytest, sqftrain, sqftest = train_test_split(data_num, target, sqf, test_size = 0.2)

#let's standard scale

sscaler = sk_prepro.StandardScaler()
sscaler_fit = sscaler.fit(xtrain)
xtrain = sscaler_fit.transform(xtrain)
xtest = sscaler_fit.transform(xtest)
#log scale the target
ytrain = np.log(ytrain)
ytest = np.log(ytest)

sqftrain = np.array(sqftrain).reshape(-1,1)
sqftest = np.array(sqftest).reshape(-1,1)

# %%
from sklearn import linear_model
line_reg = linear_model.LinearRegression()

# %%
def true_pred_plot(y_train,pred_train, y_test, pred_test):
    fig, ax = plt.subplots(2, figsize = (10,10))
    
    y_train= np.array(y_train).reshape(-1,1)
    pred_train = np.array(pred_train).reshape(-1,1)
    y_test = np.array(y_test).reshape(-1,1)
    pred_test = np.array(pred_test).reshape(-1,1)
    
    
    
    y_train = y_train*sqftrain
    pred_train = pred_train*sqftrain
    
    line_reg_train = line_reg.fit(pred_train,y_train)
    r2_train = line_reg_train.score(pred_train,y_train)
    rmse_train = (np.sqrt(metrics.mean_squared_error(y_train, pred_train))/np.mean(y_train))
    a = float(line_reg_train.coef_)
    b= line_reg_train.intercept_
    ax[0].scatter( y_train, pred_train)
    ax[0].plot([a*np.abs(b)+b, a*y_train.max()+b],[np.abs(b), y_train.max()], linestyle = 'dashed')
    ax[0].text(0.7,0.4,'R2 : {:.3f} NRMSE : {: .2f}'.format(r2_train,rmse_train), transform = ax[0].transAxes)
    ax[0].set_xlabel('True values')
    ax[0].set_ylabel('Predicted values')
    ax[0].set_xlim(y_train.min(),y_train.max())
    ax[0].set_ylim(pred_train.min(),pred_train.max())
    ax[0].set_title('On train values')

    y_test = y_test*sqftest
    pred_test = pred_test*sqftest
    
    line_reg_test  = line_reg.fit(pred_test,y_test)
    r2_test =  line_reg_test.score(pred_test,y_test)
    rmse_test = (np.sqrt(metrics.mean_squared_error(y_test, pred_test))/np.mean(y_test))
    a = float(line_reg_test.coef_)
    b=  line_reg_test.intercept_
    ax[1].scatter( y_test, pred_test)
    ax[1].plot([a*np.abs(b)+b, a*y_test.max()+b],[np.abs(b), y_test.max()], linestyle = 'dashed')
    ax[1].text(0.7,0.4,'R2 : {:.3f} NRMSE : {: .2f}'.format(r2_test, rmse_test), transform = ax[1].transAxes)
    ax[1].set_xlabel('True values')
    ax[1].set_ylabel('Predicted values')
    ax[1].set_xlim(y_test.min(),y_test.max())
    ax[1].set_ylim(pred_test.min(),pred_test.max())
    ax[1].set_title('On test values')
    
    plt.show()
    plt.clf()

# %%
df_year={}
for i in df['YearBuilt'].unique():
    df_year[f'{i}'] = df[df['YearBuilt'] == i]
len(df_year)
# Out:
# 113

# %%
def feature_error(df_lib,model,target,drop_label):
    results = []
    for i in df_lib:
        x = df_lib[str(i)]
        y = x[target]
        sqf = x['PropertyGFATotal']
        x = x.drop(axis = 1, labels = target)
        x = x.drop(axis = 1, labels = label)
        x = sscaler_fit.transform(x)
        
        y = np.array(np.log(y)).reshape(-1,1)     
        pred = model.predict(x)
        
        y = np.array(y).reshape(-1,1)
        pred = np.array(y).reshape(-1,1)
        
        sqf = np.array(sqf).reshape(-1,1)
        y = y*sqf
        pred = pred*sqf
        
        line_reg_fit  = line_reg.fit(pred,y)
        r2 =  line_reg_fit.score(pred,y)
        results.append(r2)
    return results

# %%
line_reg_m = linear_model.LinearRegression()

model_lr = line_reg_m.fit(xtrain,ytrain)


true_pred_plot(ytrain, model_lr.predict(xtrain), ytest, model_lr.predict(xtest))
# Out:
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
#let's grid search for the k

k_grid = {'n_neighbors' : list(range(2,16))}
score = 'r2'

reg = GridSearchCV(KNeighborsRegressor(), k_grid, cv =3, scoring = score, verbose = 1)

reg.fit(xtrain, ytrain)

print('Best params on training set : {}'.format(reg.best_params_))

print('GridCV results : ')
for mean, std, k in zip(reg.cv_results_['mean_test_score'],
                       reg.cv_results_['std_test_score'],
                       reg.cv_results_['params']):
    print('{} = {:.3f} (+/- {:.3f}) for {}'.format(score,mean,std*2,k))
    
model_kn = KNeighborsRegressor(n_neighbors = reg.best_params_['n_neighbors']).fit(xtrain, ytrain)

true_pred_plot(ytrain, model_kn.predict(xtrain), ytest, model_kn.predict(xtest))
# Out:
# Fitting 3 folds for each of 14 candidates, totalling 42 fits
# Best params on training set : {'n_neighbors': 6}
# GridCV results :
# r2 = 0.172 (+/- 0.120) for {'n_neighbors': 2}
# r2 = 0.246 (+/- 0.099) for {'n_neighbors': 3}
# r2 = 0.260 (+/- 0.092) for {'n_neighbors': 4}
# r2 = 0.269 (+/- 0.078) for {'n_neighbors': 5}
# r2 = 0.275 (+/- 0.073) for {'n_neighbors': 6}
# r2 = 0.273 (+/- 0.073) for {'n_neighbors': 7}
# r2 = 0.263 (+/- 0.063) for {'n_neighbors': 8}
# r2 = 0.259 (+/- 0.050) for {'n_neighbors': 9}
# r2 = 0.260 (+/- 0.038) for {'n_neighbors': 10}
# r2 = 0.258 (+/- 0.035) for {'n_neighbors': 11}
# r2 = 0.253 (+/- 0.041) for {'n_neighbors': 12}
# r2 = 0.248 (+/- 0.041) for {'n_neighbors': 13}
# r2 = 0.242 (+/- 0.039) for {'n_neighbors': 14}
# r2 = 0.239 (+/- 0.039) for {'n_neighbors': 15}
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
x = input('Do you want to launch ? [y/n]')
if x == 'y':

    #let's try with a svr
    C_range = [1.0, 5.0, 10.0, 100.0]
    kernels = ['linear', 'rbf', 'sigmoid', 'poly']
    degrees = [2,3,4]
    gamma_range  = np.logspace(-2, 1, 10)
    #gamma_range = np.logspace(-2, 1, 10)
    #'gamma' : gamma_range
    param_grid = {'gamma' : gamma_range, 'kernel' : kernels, 'degree' : degrees}

    score = 'neg_mean_squared_error'

    svr_cv = GridSearchCV(svm.SVR(), param_grid, cv = 3, scoring = score, verbose = 1)

    svr_cv.fit(xtrain, ytrain)

    print('Best params on training set : {}'.format(svr_cv.best_params_))
bkernel = svr_cv.best_params_['kernel']
bgamma = svr_cv.best_params_['gamma']
bdegree = svr_cv.best_params_['degree']
    
svr = svm.SVR(kernel=bkernel, C=1.0, gamma = bgamma, degree = bdegree)
model_svr = svr.fit(xtrain,ytrain)

true_pred_plot(ytrain, model_svr.predict(xtrain), ytest, model_svr.predict(xtest))
# Out:
# Do you want to launch ? [y/n] y
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# Best params on training set : {'degree': 2, 'gamma': 0.01, 'kernel': 'rbf'}
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
from sklearn import kernel_ridge
#let's try with a ridge regression

x = input('Do you want to launch ? [y/n]')
if x == 'y':
    alpha_range = [1.0, 5.0, 10.0, 100.0]
    kernels = ['linear', 'poly', 'rbf']
    degrees = [3,4,5]
    gamma_range  = np.logspace(-2, 1, 10)


    param_grid = {'gamma' : gamma_range, 'kernel' : kernels, 'degree' : degrees, 'alpha' : alpha_range}
    
    score = 'neg_mean_absolute_percentage_error'

    kernel_ridge_cv = GridSearchCV(kernel_ridge.KernelRidge(), param_grid, cv = 3, scoring = score, verbose = 1)

    kernel_ridge_cv.fit(xtrain, ytrain)

    print('Best params on training set : {}'.format(kernel_ridge_cv.best_params_))
    
bkernel = kernel_ridge_cv.best_params_['kernel']
bgamma = kernel_ridge_cv.best_params_['gamma']
bdegree = kernel_ridge_cv.best_params_['degree']
balpha = kernel_ridge_cv.best_params_['alpha']

model = kernel_ridge.KernelRidge(alpha = balpha, kernel = bkernel, degree = bdegree, gamma = bgamma)
model_krr = model.fit(xtrain, ytrain)

true_pred_plot(ytrain, model_krr.predict(xtrain), ytest, model_krr.predict(xtest))
# Out:
# Do you want to launch ? [y/n] y
# Fitting 3 folds for each of 360 candidates, totalling 1080 fits
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.1627e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.53846e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.44157e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.42019e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.41083e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.75483e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.44621e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.42029e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.41083e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.02745e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.45201e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.42041e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.41083e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.21772e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.55665e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.42266e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.41088e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Best params on training set : {'alpha': 5.0, 'degree': 3, 'gamma': 0.01, 'kernel': 'poly'}
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %% [markdown]
# ## Neural network

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
#test with a single perceptron
model1 = keras.Sequential()
model1.add(keras.Input(shape = xtrain.shape[1]))
model1.add(layers.Dense(1,input_dim = 2, activation = 'linear'))

model1.compile(metrics = [tf.keras.metrics.RootMeanSquaredError()], loss = 'mean_absolute_percentage_error', optimizer = 'adam')

model1.summary()

history1 = model1.fit(xtrain, ytrain, epochs = 50, batch_size = 1, verbose = 1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 523
#
# =================================================================
# Total params: 523
# Trainable params: 523
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1304/1304 [==============================] - 2s 880us/step - loss: 117.5653 - root_mean_squared_error: 8.5642
# Epoch 2/50
# 1304/1304 [==============================] - 1s 886us/step - loss: 90.8204 - root_mean_squared_error: 7.5806
# Epoch 3/50
# 1304/1304 [==============================] - 1s 881us/step - loss: 81.3113 - root_mean_squared_error: 7.0022
# Epoch 4/50
# 1304/1304 [==============================] - 1s 851us/step - loss: 73.0797 - root_mean_squared_error: 6.4445
# Epoch 5/50
# 1304/1304 [==============================] - 1s 820us/step - loss: 65.9648 - root_mean_squared_error: 5.9152
# Epoch 6/50
# 1304/1304 [==============================] - 1s 820us/step - loss: 59.3575 - root_mean_squared_error: 5.4430
# Epoch 7/50
# 1304/1304 [==============================] - 1s 817us/step - loss: 53.8548 - root_mean_squared_error: 4.9610
# Epoch 8/50
# 1304/1304 [==============================] - 1s 824us/step - loss: 48.5065 - root_mean_squared_error: 4.5217
# Epoch 9/50
# 1304/1304 [==============================] - 1s 827us/step - loss: 43.5671 - root_mean_squared_error: 4.0971
# Epoch 10/50
# 1304/1304 [==============================] - 1s 880us/step - loss: 39.5467 - root_mean_squared_error: 3.6939
# Epoch 11/50
# 1304/1304 [==============================] - 1s 857us/step - loss: 35.3902 - root_mean_squared_error: 3.3133
# Epoch 12/50
# 1304/1304 [==============================] - 1s 822us/step - loss: 31.8717 - root_mean_squared_error: 2.9464
# Epoch 13/50
# 1304/1304 [==============================] - 1s 819us/step - loss: 28.9252 - root_mean_squared_error: 2.6154
# Epoch 14/50
# 1304/1304 [==============================] - 1s 823us/step - loss: 25.9381 - root_mean_squared_error: 2.2981
# Epoch 15/50
# 1304/1304 [==============================] - 1s 819us/step - loss: 23.4965 - root_mean_squared_error: 1.9935
# Epoch 16/50
# 1304/1304 [==============================] - 1s 830us/step - loss: 21.2177 - root_mean_squared_error: 1.7474
# Epoch 17/50
# 1304/1304 [==============================] - 1s 826us/step - loss: 19.8344 - root_mean_squared_error: 1.5211
# Epoch 18/50
# 1304/1304 [==============================] - 1s 825us/step - loss: 18.0157 - root_mean_squared_error: 1.3188
# Epoch 19/50
# 1304/1304 [==============================] - 1s 817us/step - loss: 17.3581 - root_mean_squared_error: 1.1534
# Epoch 20/50
# 1304/1304 [==============================] - 1s 830us/step - loss: 15.9071 - root_mean_squared_error: 1.0144
# Epoch 21/50
# 1304/1304 [==============================] - 1s 859us/step - loss: 15.9053 - root_mean_squared_error: 0.9016
# Epoch 22/50
# 1304/1304 [==============================] - 1s 843us/step - loss: 15.0435 - root_mean_squared_error: 0.8261
# Epoch 23/50
# 1304/1304 [==============================] - 1s 834us/step - loss: 14.9053 - root_mean_squared_error: 0.7607
# Epoch 24/50
# 1304/1304 [==============================] - 1s 865us/step - loss: 14.3284 - root_mean_squared_error: 0.7122
# Epoch 25/50
# 1304/1304 [==============================] - 1s 892us/step - loss: 14.7621 - root_mean_squared_error: 0.7268
# Epoch 26/50
# 1304/1304 [==============================] - 1s 829us/step - loss: 14.2742 - root_mean_squared_error: 0.7055
# Epoch 27/50
# 1304/1304 [==============================] - 1s 821us/step - loss: 14.5340 - root_mean_squared_error: 0.7111
# Epoch 28/50
# 1304/1304 [==============================] - 1s 822us/step - loss: 14.1203 - root_mean_squared_error: 0.7149
# Epoch 29/50
# 1304/1304 [==============================] - 1s 826us/step - loss: 14.3622 - root_mean_squared_error: 0.7164
# Epoch 30/50
# 1304/1304 [==============================] - 1s 815us/step - loss: 14.0118 - root_mean_squared_error: 0.7022
# Epoch 31/50
# 1304/1304 [==============================] - 1s 856us/step - loss: 14.3996 - root_mean_squared_error: 0.7101
# Epoch 32/50
# 1304/1304 [==============================] - 1s 865us/step - loss: 14.0328 - root_mean_squared_error: 0.6930
# Epoch 33/50
# 1304/1304 [==============================] - 1s 850us/step - loss: 14.3422 - root_mean_squared_error: 0.7071
# Epoch 34/50
# 1304/1304 [==============================] - 1s 896us/step - loss: 14.0824 - root_mean_squared_error: 0.6898
# Epoch 35/50
# 1304/1304 [==============================] - 1s 864us/step - loss: 14.4634 - root_mean_squared_error: 0.7064
# Epoch 36/50
# 1304/1304 [==============================] - 1s 864us/step - loss: 14.0396 - root_mean_squared_error: 0.6954
# Epoch 37/50
# 1304/1304 [==============================] - 1s 881us/step - loss: 14.3598 - root_mean_squared_error: 0.7063
# Epoch 38/50
# 1304/1304 [==============================] - 1s 821us/step - loss: 14.0148 - root_mean_squared_error: 0.6898
# Epoch 39/50
# 1304/1304 [==============================] - 1s 857us/step - loss: 14.4052 - root_mean_squared_error: 0.7085
# Epoch 40/50
# 1304/1304 [==============================] - 1s 850us/step - loss: 13.8701 - root_mean_squared_error: 0.6810
# Epoch 41/50
# 1304/1304 [==============================] - 1s 867us/step - loss: 14.2368 - root_mean_squared_error: 0.7026
# Epoch 42/50
# 1304/1304 [==============================] - 1s 861us/step - loss: 13.7809 - root_mean_squared_error: 0.6800
# Epoch 43/50
# 1304/1304 [==============================] - 1s 860us/step - loss: 14.2395 - root_mean_squared_error: 0.7042
# Epoch 44/50
# 1304/1304 [==============================] - 1s 867us/step - loss: 14.0998 - root_mean_squared_error: 0.6904
# Epoch 45/50
# 1304/1304 [==============================] - 1s 866us/step - loss: 14.0864 - root_mean_squared_error: 0.7009
# Epoch 46/50
# 1304/1304 [==============================] - 1s 878us/step - loss: 13.9601 - root_mean_squared_error: 0.6890
# Epoch 47/50
# 1304/1304 [==============================] - 1s 870us/step - loss: 14.3362 - root_mean_squared_error: 0.7107
# Epoch 48/50
# 1304/1304 [==============================] - 1s 868us/step - loss: 13.6035 - root_mean_squared_error: 0.6811
# Epoch 49/50
# 1304/1304 [==============================] - 1s 828us/step - loss: 14.3828 - root_mean_squared_error: 0.6998
# Epoch 50/50
# 1304/1304 [==============================] - 1s 827us/step - loss: 13.7569 - root_mean_squared_error: 0.6759

# %%
true_pred_plot(ytrain, np.array(model1.predict(xtrain)).reshape(-1,1), ytest, np.array(model1.predict(xtest)).reshape(-1,1))
# Out:
# 41/41 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 800us/step
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
model2 = keras.Sequential(
    [
        layers.Dense(xtrain.shape[1], activation="selu", name="layer1", input_shape=(xtrain.shape[1],), input_dim = 2),
        layers.Dense(287, activation="selu", name="layer2"),
        layers.Dense(1, activation = 'linear', name="layer3"),
    ]
)

model2.compile(metrics = [tf.keras.metrics.RootMeanSquaredError()], loss = 'mean_absolute_percentage_error', optimizer = 'adam')

model2.summary()

history2 = model2.fit(xtrain, ytrain, epochs = 50, batch_size = 1, verbose = 1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 522)               273006
#
#  layer2 (Dense)              (None, 287)               150101
#
#  layer3 (Dense)              (None, 1)                 288
#
# =================================================================
# Total params: 423,395
# Trainable params: 423,395
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 61.0758 - root_mean_squared_error: 3.5663
# Epoch 2/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 28.1066 - root_mean_squared_error: 1.4348
# Epoch 3/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 26.1718 - root_mean_squared_error: 1.3387
# Epoch 4/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 25.8405 - root_mean_squared_error: 1.3138
# Epoch 5/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 23.5721 - root_mean_squared_error: 1.2168
# Epoch 6/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 21.8575 - root_mean_squared_error: 1.1391
# Epoch 7/50
# 1304/1304 [==============================] - 2s 2ms/step - loss: 18.4028 - root_mean_squared_error: 0.8948
# Epoch 8/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 17.7285 - root_mean_squared_error: 0.8531
# Epoch 9/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 17.2905 - root_mean_squared_error: 0.8286
# Epoch 10/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 17.8748 - root_mean_squared_error: 0.8754
# Epoch 11/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 17.0971 - root_mean_squared_error: 0.8189
# Epoch 12/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 17.4038 - root_mean_squared_error: 0.9035
# Epoch 13/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 18.0659 - root_mean_squared_error: 0.8920
# Epoch 14/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.3671 - root_mean_squared_error: 0.7805
# Epoch 15/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.3869 - root_mean_squared_error: 0.8106
# Epoch 16/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.9336 - root_mean_squared_error: 0.7563
# Epoch 17/50
# 1304/1304 [==============================] - 2s 2ms/step - loss: 15.7616 - root_mean_squared_error: 0.7446
# Epoch 18/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.9483 - root_mean_squared_error: 0.7310
# Epoch 19/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.2576 - root_mean_squared_error: 0.7647
# Epoch 20/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.2958 - root_mean_squared_error: 0.7578
# Epoch 21/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.3951 - root_mean_squared_error: 0.7286
# Epoch 22/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.5075 - root_mean_squared_error: 0.7321
# Epoch 23/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.3663 - root_mean_squared_error: 0.7317
# Epoch 24/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.0140 - root_mean_squared_error: 0.7176
# Epoch 25/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.3714 - root_mean_squared_error: 0.8310
# Epoch 26/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.3167 - root_mean_squared_error: 0.6995
# Epoch 27/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.6033 - root_mean_squared_error: 0.7238
# Epoch 28/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.7691 - root_mean_squared_error: 0.7071
# Epoch 29/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.5788 - root_mean_squared_error: 0.7382
# Epoch 30/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.0151 - root_mean_squared_error: 0.7038
# Epoch 31/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.2687 - root_mean_squared_error: 0.6517
# Epoch 32/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.4387 - root_mean_squared_error: 0.7631
# Epoch 33/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.1481 - root_mean_squared_error: 0.6977
# Epoch 34/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.8174 - root_mean_squared_error: 0.7039
# Epoch 35/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.0299 - root_mean_squared_error: 0.6511
# Epoch 36/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.3201 - root_mean_squared_error: 0.6680
# Epoch 37/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.6406 - root_mean_squared_error: 0.6922
# Epoch 38/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.5658 - root_mean_squared_error: 0.6847
# Epoch 39/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.3170 - root_mean_squared_error: 0.6551
# Epoch 40/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.4678 - root_mean_squared_error: 0.7160
# Epoch 41/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.6257 - root_mean_squared_error: 0.6731
# Epoch 42/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.7587 - root_mean_squared_error: 0.7426
# Epoch 43/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.8258 - root_mean_squared_error: 0.6858
# Epoch 44/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.0255 - root_mean_squared_error: 0.6580
# Epoch 45/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.9866 - root_mean_squared_error: 0.7142
# Epoch 46/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.9827 - root_mean_squared_error: 0.6981
# Epoch 47/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 13.4408 - root_mean_squared_error: 0.6344
# Epoch 48/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.5510 - root_mean_squared_error: 0.6840
# Epoch 49/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.5357 - root_mean_squared_error: 0.6725
# Epoch 50/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.2945 - root_mean_squared_error: 0.6629

# %%
true_pred_plot(ytrain, model2.predict(xtrain), ytest, model2.predict(xtest))
# Out:
# 41/41 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
#now with a multi layer network

model3 = keras.Sequential(
    [
        layers.Dense(xtrain.shape[1], activation="selu", name="layer1", input_shape=(xtrain.shape[1],), input_dim = 2),
        layers.Dense(383, activation="selu", name="layer2a"),
        layers.Dense(287, activation="selu", name="layer2"),
        layers.Dense(82, activation="selu", name="layer3"),
        layers.Dense(20, activation="selu", name="layer4"),
        layers.Dense(1, activation = 'linear', name="layer6"),
    ]
)

model3.compile(metrics = [tf.keras.metrics.RootMeanSquaredError()], loss = 'mean_absolute_percentage_error', optimizer = 'adam')

model3.summary()

history3 = model3.fit(xtrain, ytrain, epochs = 50, batch_size = 1, verbose = 1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 522)               273006
#
#  layer2a (Dense)             (None, 383)               200309
#
#  layer2 (Dense)              (None, 287)               110208
#
#  layer3 (Dense)              (None, 82)                23616
#
#  layer4 (Dense)              (None, 20)                1660
#
#  layer6 (Dense)              (None, 1)                 21
#
# =================================================================
# Total params: 608,820
# Trainable params: 608,820
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1304/1304 [==============================] - 4s 2ms/step - loss: 43.6638 - root_mean_squared_error: 2.6581
# Epoch 2/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 22.4566 - root_mean_squared_error: 1.1986
# Epoch 3/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 18.3330 - root_mean_squared_error: 0.9201
# Epoch 4/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 16.6239 - root_mean_squared_error: 0.8582
# Epoch 5/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.8501 - root_mean_squared_error: 0.7494
# Epoch 6/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 15.3058 - root_mean_squared_error: 0.7248
# Epoch 7/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 14.7059 - root_mean_squared_error: 0.7036
# Epoch 8/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 15.4486 - root_mean_squared_error: 0.9228
# Epoch 9/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 14.0962 - root_mean_squared_error: 0.6748
# Epoch 10/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 15.6670 - root_mean_squared_error: 1.5755
# Epoch 11/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 14.0051 - root_mean_squared_error: 0.8223
# Epoch 12/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 12.9913 - root_mean_squared_error: 0.6191
# Epoch 13/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 13.4063 - root_mean_squared_error: 1.1861
# Epoch 14/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 13.0763 - root_mean_squared_error: 0.7667
# Epoch 15/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 12.5299 - root_mean_squared_error: 0.5834
# Epoch 16/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 24.5514 - root_mean_squared_error: 11.7879
# Epoch 17/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 12.0992 - root_mean_squared_error: 0.5860
# Epoch 18/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.3990 - root_mean_squared_error: 0.5476
# Epoch 19/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.1734 - root_mean_squared_error: 0.5437
# Epoch 20/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.4447 - root_mean_squared_error: 0.5883
# Epoch 21/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.3010 - root_mean_squared_error: 0.5374
# Epoch 22/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.5171 - root_mean_squared_error: 0.5586
# Epoch 23/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.6303 - root_mean_squared_error: 0.5603
# Epoch 24/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.9149 - root_mean_squared_error: 0.6975
# Epoch 25/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.5033 - root_mean_squared_error: 0.5504
# Epoch 26/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 12.7396 - root_mean_squared_error: 1.6096
# Epoch 27/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 20.1071 - root_mean_squared_error: 9.8565
# Epoch 28/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.8213 - root_mean_squared_error: 0.5235
# Epoch 29/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.4186 - root_mean_squared_error: 6.3720
# Epoch 30/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.7166 - root_mean_squared_error: 0.5871
# Epoch 31/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 56.9348 - root_mean_squared_error: 85.6749
# Epoch 32/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.5531 - root_mean_squared_error: 0.5408
# Epoch 33/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.3874 - root_mean_squared_error: 0.5214
# Epoch 34/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.7427 - root_mean_squared_error: 0.5432
# Epoch 35/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.0984 - root_mean_squared_error: 0.5047
# Epoch 36/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.3655 - root_mean_squared_error: 0.5101
# Epoch 37/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 75.5118 - root_mean_squared_error: 49.3783
# Epoch 38/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.3198 - root_mean_squared_error: 0.5280
# Epoch 39/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 9.8868 - root_mean_squared_error: 0.5081
# Epoch 40/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 9.7718 - root_mean_squared_error: 0.4946
# Epoch 41/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.2001 - root_mean_squared_error: 0.5239
# Epoch 42/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.1762 - root_mean_squared_error: 0.5108
# Epoch 43/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.2128 - root_mean_squared_error: 0.5095
# Epoch 44/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.8009 - root_mean_squared_error: 0.5963
# Epoch 45/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 14.2494 - root_mean_squared_error: 4.4047
# Epoch 46/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.9004 - root_mean_squared_error: 0.6730
# Epoch 47/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 10.5294 - root_mean_squared_error: 0.5096
# Epoch 48/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 10.1287 - root_mean_squared_error: 0.4918
# Epoch 49/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 10.1627 - root_mean_squared_error: 0.5160
# Epoch 50/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 10.2786 - root_mean_squared_error: 0.5124

# %%
true_pred_plot(ytrain, model3.predict(xtrain), ytest, model3.predict(xtest))
# Out:
# 41/41 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators=500, verbose = 1)

model_rfr = rfr.fit(xtrain,ytrain)

true_pred_plot(ytrain, model_rfr.predict(xtrain), ytest, model_rfr.predict(xtest))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:   12.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:    0.0s finished
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(n_estimators = 500, verbose = 1)
model_xgb = gbr.fit(xtrain, ytrain)

true_pred_plot(ytrain, model_xgb.predict(xtrain), ytest, model_xgb.predict(xtest))
# Out:
#       Iter       Train Loss   Remaining Time
#          1           0.6127            4.49s
#          2           0.5812            4.48s
#          3           0.5547            4.47s
#          4           0.5319            4.46s
#          5           0.5107            4.55s
#          6           0.4933            4.61s
#          7           0.4779            4.58s
#          8           0.4648            4.49s
#          9           0.4517            4.47s
#         10           0.4413            4.41s
#         20           0.3660            4.25s
#         30           0.3236            4.14s
#         40           0.2981            4.00s
#         50           0.2801            3.88s
#         60           0.2667            3.78s
#         70           0.2565            3.70s
#         80           0.2454            3.60s
#         90           0.2359            3.49s
#        100           0.2251            3.38s
#        200           0.1723            2.49s
#        300           0.1449            1.66s
#        400           0.1230            0.82s
#        500           0.1053            0.00s
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
importance = model_xgb.feature_importances_
nul_col = []
for i,v in enumerate(importance):
    if v == 0:
        nul_col.append(i)
print(nul_col)
# plot feature importance
fig, ax = plt.subplots(figsize = (20,20))
ax.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# [3, 8, 11, 14, 16, 17, 24, 32, 41, 43, 46, 47, 49, 53, 55, 57, 58, 59, 60, 61, 63, 65, 67, 68, 69, 70, 71, 73, 74, 76, 77, 80, 81, 83, 84, 85, 86, 87, 89, 91, 93, 95, 97, 101, 102, 103, 104, 105, 110, 111, 112, 114, 115, 118, 121, 122, 123, 124, 125, 127, 128, 129, 130, 132, 133, 134, 136, 138, 139, 141, 142, 143, 144, 145, 149, 150, 151, 152, 154, 157, 158, 159, 161, 162, 163, 166, 168, 170, 171, 172, 173, 174, 176, 177, 178, 179, 180, 181, 184, 187, 188, 189, 190, 191, 192, 193, 194, 197, 202, 203, 205, 206, 209, 211, 213, 214, 216, 217, 219, 220, 221, 224, 225, 226, 227, 230, 232, 236, 237, 238, 239, 240, 242, 243, 248, 249, 250, 251, 252, 258, 261, 263, 267, 268, 269, 270, 275, 276, 278, 279, 281, 283, 286, 287, 288, 289, 290, 291, 294, 295, 296, 297, 298, 299, 300, 301, 305, 306, 308, 309, 310, 311, 314, 315, 318, 321, 322, 324, 325, 327, 328, 330, 333, 335, 336, 337, 339, 340, 341, 342, 343, 346, 348, 349, 350, 353, 355, 356, 357, 358, 359, 360, 364, 366, 367, 368, 371, 372, 373, 375, 376, 378, 380, 382, 385, 386, 387, 388, 389, 390, 392, 393, 394, 397, 398, 399, 400, 404, 405, 406, 408, 409, 410, 411, 413, 415, 417, 418, 424, 425, 426, 427, 434, 442, 443, 444, 445, 446, 449, 453, 454, 455, 456, 460, 461, 464, 468, 469, 477, 478, 479, 483, 485, 487, 489, 490, 493, 494, 496, 497, 498, 499, 500, 504, 506, 508, 509]

# %%
def r2(pred,y):
    pred = np.array(pred).reshape(-1,1)
    y = np.array(y).reshape(-1,1)
    
    pred = pred*sqftest
    y = y*sqftest
    
    line_reg_test  = line_reg.fit(pred,y)
    r2_value =  line_reg_test.score(pred,y)
    return r2_value

def rmse(pred,y):
    pred = np.array(pred).reshape(-1,1)
    y = np.array(y).reshape(-1,1)
    
    pred = pred*sqftest
    y = y*sqftest
    
    rmse_value = np.sqrt(metrics.mean_squared_error(y,pred))
    return rmse_value

def nrmse(pred,y):
    pred = np.array(pred).reshape(-1,1)
    y = np.array(y).reshape(-1,1)
    
    pred = pred*sqftest
    y = y*sqftest
    
    nrmse_value = (np.sqrt(metrics.mean_squared_error(y,pred))/np.mean(y))
    return nrmse_value
                   
def mae(pred,y):
    pred = np.array(pred).reshape(-1,1)
    y = np.array(y).reshape(-1,1)
    
    pred = pred*sqftest
    y = y*sqftest
    
    mae_value = metrics.mean_absolute_error(y,pred)
    return mae_value

# %%
# Out:
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 2ms/step
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:    0.0s finished
