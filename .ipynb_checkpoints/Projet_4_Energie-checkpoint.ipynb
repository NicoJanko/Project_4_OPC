# %% [markdown]
# # Modelisation de la consommation totale d'energie

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
import sklearn.preprocessing as sk_prepro
from sklearn import metrics

# %%
df = pd.read_csv('data_full.csv')

# %%
data_num = df
target_tag = 'SiteEUI(kBtu/sf)'
target = data_num[target_tag]
label = ['TotalGHGEmissions', 'ENERGYSTARScore','SiteEnergyUse(kBtu)', 'GHGEmissionsIntensity']
sqf = data_num['PropertyGFABuilding(s)']
data_num = data_num.drop(labels = [target_tag, 'TotalGHGEmissions', 'ENERGYSTARScore','SiteEnergyUse(kBtu)', 'GHGEmissionsIntensity'], axis = 1)

col_name_lib = {}
col_name = data_num.columns
for i,v in enumerate(col_name):
    col_name_lib[f'{i}'] = v

# %%
data_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1630 entries, 0 to 1629
# Columns: 522 entries, BuildingType_Campus to ThirdLargestPropertyUseTypeGFA
# dtypes: float64(522)
# memory usage: 6.5 MB

# %% [markdown]
# ## Modèle linéaire

# %%
from sklearn.linear_model import Ridge
from sklearn import svm
from sklearn.neighbors import KNeighborsRegressor

# %%
#first let's test this on knregressoe
xtrain, xtest, ytrain, ytest, sqftrain, sqftest = train_test_split(data_num, target, sqf, test_size = 0.2)

df_res = xtrain

#let's standard scale

sscaler = sk_prepro.StandardScaler()
sscaler_fit = sscaler.fit(xtrain)
xtrain = sscaler_fit.transform(xtrain)
xtest = sscaler_fit.transform(xtest)
#log scale the target
ytrain = np.log(ytrain)
ytest = np.log(ytest)

sqftrain = np.array(sqftrain).reshape(-1,1)
sqftest = np.array(sqftest).reshape(-1,1)

# %%
from sklearn import linear_model
line_reg = linear_model.LinearRegression()

# %%
def true_pred_plot(y_train,pred_train, y_test, pred_test):
    fig, ax = plt.subplots(2, figsize = (10,10))
    
    y_train= np.array(np.exp(y_train)).reshape(-1,1)
    pred_train = np.array(np.exp(pred_train)).reshape(-1,1)
    y_test = np.array(np.exp(y_test)).reshape(-1,1)
    pred_test = np.array(np.exp(pred_test)).reshape(-1,1)
    
    
    
    y_train = y_train*sqftrain
    pred_train = pred_train*sqftrain
    
    line_reg_train = line_reg.fit(pred_train,y_train)
    r2_train = line_reg_train.score(pred_train,y_train)
    rmse_train = (np.sqrt(metrics.mean_squared_error(y_train, pred_train))/np.mean(y_train))
    a = float(line_reg_train.coef_)
    b= line_reg_train.intercept_
    ax[0].scatter( y_train, pred_train)
    ax[0].plot([a*np.abs(b)+b, a*y_train.max()+b],[np.abs(b), y_train.max()], linestyle = 'dashed')
    ax[0].text(0.7,0.4,'R2 : {:.3f} NRMSE : {: .2f}'.format(r2_train,rmse_train), transform = ax[0].transAxes)
    ax[0].set_xlabel('True values')
    ax[0].set_ylabel('Predicted values')
    ax[0].set_xlim(y_train.min(),y_train.max())
    ax[0].set_ylim(pred_train.min(),pred_train.max())
    ax[0].set_title('On train values')

    y_test = y_test*sqftest
    pred_test = pred_test*sqftest
    
    line_reg_test  = line_reg.fit(pred_test,y_test)
    r2_test =  line_reg_test.score(pred_test,y_test)
    rmse_test = (np.sqrt(metrics.mean_squared_error(y_test, pred_test))/np.mean(y_test))
    a = float(line_reg_test.coef_)
    b=  line_reg_test.intercept_
    ax[1].scatter( y_test, pred_test)
    ax[1].plot([a*np.abs(b)+b, a*y_test.max()+b],[np.abs(b), y_test.max()], linestyle = 'dashed')
    ax[1].text(0.7,0.4,'R2 : {:.3f} NRMSE : {: .2f}'.format(r2_test, rmse_test), transform = ax[1].transAxes)
    ax[1].set_xlabel('True values')
    ax[1].set_ylabel('Predicted values')
    ax[1].set_xlim(y_test.min(),y_test.max())
    ax[1].set_ylim(pred_test.min(),pred_test.max())
    ax[1].set_title('On test values')
    
    plt.show()
    plt.clf()

# %%
df_year={}
for i in df['YearBuilt'].unique():
    df_year[f'{i}'] = df[df['YearBuilt'] == i]
len(df_year)
# Out:
# 113

# %%
def feature_error(df_lib,model,target,drop_label):
    results = []
    for i in df_lib:
        x = df_lib[str(i)]
        y = x[target]
        sqf = x['PropertyGFATotal']
        x = x.drop(axis = 1, labels = target)
        x = x.drop(axis = 1, labels = label)
        x = sscaler_fit.transform(x)
        
        y = np.array(np.log(y)).reshape(-1,1)     
        pred = model.predict(x)
        
        y = np.array(y).reshape(-1,1)
        pred = np.array(y).reshape(-1,1)
        
        sqf = np.array(sqf).reshape(-1,1)
        y = y*sqf
        pred = pred*sqf
        
        line_reg_fit  = line_reg.fit(pred,y)
        r2 =  line_reg_fit.score(pred,y)
        results.append(r2)
    return results

# %%
line_reg_m = linear_model.LinearRegression()

model_lr = line_reg_m.fit(xtrain,ytrain)


true_pred_plot(ytrain, model_lr.predict(xtrain), ytest, model_lr.predict(xtest))
# Out:
# E:\temp\ipykernel_9908\1743394803.py:7: RuntimeWarning: overflow encountered in exp
#   pred_test = np.array(np.exp(pred_test)).reshape(-1,1)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [81], in <cell line: 6>()
#       1 line_reg_m = linear_model.LinearRegression()
#       3 model_lr = line_reg_m.fit(xtrain,ytrain)
# ----> 6 true_pred_plot(ytrain, model_lr.predict(xtrain), ytest, model_lr.predict(xtest))
#
# Input In [80], in true_pred_plot(y_train, pred_train, y_test, pred_test)
#      28 y_test = y_test*sqftest
#      29 pred_test = pred_test*sqftest
# ---> 31 line_reg_test  = line_reg.fit(pred_test,y_test)
#      32 r2_test =  line_reg_test.score(pred_test,y_test)
#      33 rmse_test = (np.sqrt(metrics.mean_squared_error(y_test, pred_test))/np.mean(y_test))
#
# File E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File E:\Data_Science\Anaconda\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     579         y = check_array(y, **check_y_params)
#     580     else:
# --> 581         X, y = check_X_y(X, y, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
#
# File E:\Data_Science\Anaconda\lib\site-packages\sklearn\utils\validation.py:964, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     961 if y is None:
#     962     raise ValueError("y cannot be None")
# --> 964 X = check_array(
#     965     X,
#     966     accept_sparse=accept_sparse,
#     967     accept_large_sparse=accept_large_sparse,
#     968     dtype=dtype,
#     969     order=order,
#     970     copy=copy,
#     971     force_all_finite=force_all_finite,
#     972     ensure_2d=ensure_2d,
#     973     allow_nd=allow_nd,
#     974     ensure_min_samples=ensure_min_samples,
#     975     ensure_min_features=ensure_min_features,
#     976     estimator=estimator,
#     977 )
#     979 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     981 check_consistent_length(X, y)
#
# File E:\Data_Science\Anaconda\lib\site-packages\sklearn\utils\validation.py:800, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     794         raise ValueError(
#     795             "Found array with dim %d. %s expected <= 2."
#     796             % (array.ndim, estimator_name)
#     797         )
#     799     if force_all_finite:
# --> 800         _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     802 if ensure_min_samples > 0:
#     803     n_samples = _num_samples(array)
#
# File E:\Data_Science\Anaconda\lib\site-packages\sklearn\utils\validation.py:114, in _assert_all_finite(X, allow_nan, msg_dtype)
#     107     if (
#     108         allow_nan
#     109         and np.isinf(X).any()
#     110         or not allow_nan
#     111         and not np.isfinite(X).all()
#     112     ):
#     113         type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114         raise ValueError(
#     115             msg_err.format(
#     116                 type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117             )
#     118         )
#     119 # for object dtype data, we only check for NaNs (GH-13254)
#     120 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
#let's grid search for the k

k_grid = {'n_neighbors' : list(range(2,16))}
score = 'r2'

reg = GridSearchCV(KNeighborsRegressor(), k_grid, cv =3, scoring = score, verbose = 1)

reg.fit(xtrain, ytrain)

print('Best params on training set : {}'.format(reg.best_params_))

print('GridCV results : ')
for mean, std, k in zip(reg.cv_results_['mean_test_score'],
                       reg.cv_results_['std_test_score'],
                       reg.cv_results_['params']):
    print('{} = {:.3f} (+/- {:.3f}) for {}'.format(score,mean,std*2,k))
    
model_kn = KNeighborsRegressor(n_neighbors = reg.best_params_['n_neighbors']).fit(xtrain, ytrain)

true_pred_plot(ytrain, model_kn.predict(xtrain), ytest, model_kn.predict(xtest))
# Out:
# Fitting 3 folds for each of 14 candidates, totalling 42 fits
# Best params on training set : {'n_neighbors': 4}
# GridCV results :
# r2 = 0.198 (+/- 0.098) for {'n_neighbors': 2}
# r2 = 0.241 (+/- 0.067) for {'n_neighbors': 3}
# r2 = 0.279 (+/- 0.053) for {'n_neighbors': 4}
# r2 = 0.275 (+/- 0.061) for {'n_neighbors': 5}
# r2 = 0.275 (+/- 0.060) for {'n_neighbors': 6}
# r2 = 0.268 (+/- 0.048) for {'n_neighbors': 7}
# r2 = 0.266 (+/- 0.035) for {'n_neighbors': 8}
# r2 = 0.265 (+/- 0.032) for {'n_neighbors': 9}
# r2 = 0.263 (+/- 0.023) for {'n_neighbors': 10}
# r2 = 0.258 (+/- 0.025) for {'n_neighbors': 11}
# r2 = 0.253 (+/- 0.024) for {'n_neighbors': 12}
# r2 = 0.250 (+/- 0.023) for {'n_neighbors': 13}
# r2 = 0.252 (+/- 0.015) for {'n_neighbors': 14}
# r2 = 0.246 (+/- 0.025) for {'n_neighbors': 15}
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
x = input('Do you want to launch ? [y/n]')
if x == 'y':

    #let's try with a svr
    C_range = [1.0, 5.0, 10.0, 100.0]
    kernels = ['linear', 'rbf', 'sigmoid', 'poly']
    degrees = [2,3,4]
    gamma_range  = np.logspace(-2, 1, 10)
    #gamma_range = np.logspace(-2, 1, 10)
    #'gamma' : gamma_range
    param_grid = {'gamma' : gamma_range, 'kernel' : kernels, 'degree' : degrees}

    score = 'neg_mean_squared_error'

    svr_cv = GridSearchCV(svm.SVR(), param_grid, cv = 3, scoring = score, verbose = 1)

    svr_cv.fit(xtrain, ytrain)

    print('Best params on training set : {}'.format(svr_cv.best_params_))
bkernel = svr_cv.best_params_['kernel']
bgamma = svr_cv.best_params_['gamma']
bdegree = svr_cv.best_params_['degree']
    
svr = svm.SVR(kernel=bkernel, C=1.0, gamma = bgamma, degree = bdegree)
model_svr = svr.fit(xtrain,ytrain)

true_pred_plot(ytrain, model_svr.predict(xtrain), ytest, model_svr.predict(xtest))
# Out:
# Do you want to launch ? [y/n] y
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# Best params on training set : {'degree': 2, 'gamma': 0.01, 'kernel': 'rbf'}
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
from sklearn import kernel_ridge
#let's try with a ridge regression

x = input('Do you want to launch ? [y/n]')
if x == 'y':
    alpha_range = [1.0, 5.0, 10.0, 100.0]
    kernels = ['linear', 'poly', 'rbf']
    degrees = [3,4,5]
    gamma_range  = np.logspace(-2, 1, 10)


    param_grid = {'gamma' : gamma_range, 'kernel' : kernels, 'degree' : degrees, 'alpha' : alpha_range}
    
    score = 'neg_mean_absolute_percentage_error'

    kernel_ridge_cv = GridSearchCV(kernel_ridge.KernelRidge(), param_grid, cv = 3, scoring = score, verbose = 1)

    kernel_ridge_cv.fit(xtrain, ytrain)

    print('Best params on training set : {}'.format(kernel_ridge_cv.best_params_))
    
bkernel = kernel_ridge_cv.best_params_['kernel']
bgamma = kernel_ridge_cv.best_params_['gamma']
bdegree = kernel_ridge_cv.best_params_['degree']
balpha = kernel_ridge_cv.best_params_['alpha']

model = kernel_ridge.KernelRidge(alpha = balpha, kernel = bkernel, degree = bdegree, gamma = bgamma)
model_krr = model.fit(xtrain, ytrain)

true_pred_plot(ytrain, model_krr.predict(xtrain), ytest, model_krr.predict(xtest))
# Out:
# Do you want to launch ? [y/n] y
# Fitting 3 folds for each of 360 candidates, totalling 1080 fits
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.62218e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.07067e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.07902e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.7422e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.56971e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=8.77649e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.60537e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.29163e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.84656e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.56783e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.18933e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.71356e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.55105e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.14268e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.65862e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.9781e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.80439e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.15224e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.61045e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.2967e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.90563e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.56793e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.18944e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.71483e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.55105e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.14268e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.65864e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.27398e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=8.0975e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.49648e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.6168e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.30303e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.97949e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.56807e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.18957e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.71642e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.55106e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.14269e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.65868e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=8.71387e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.76843e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.73114e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.41699e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=9.30979e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.57053e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.19203e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.74507e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.55111e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.14274e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.6593e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Best params on training set : {'alpha': 5.0, 'degree': 3, 'gamma': 0.01, 'kernel': 'poly'}
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %% [markdown]
# ## Neural network

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
#test with a single perceptron
model1 = keras.Sequential()
model1.add(keras.Input(shape = xtrain.shape[1]))
model1.add(layers.Dense(1,input_dim = 2, activation = 'linear'))

model1.compile(metrics = [tf.keras.metrics.RootMeanSquaredError()], loss = 'mean_absolute_percentage_error', optimizer = 'adam')

model1.summary()

history1 = model1.fit(xtrain, ytrain, epochs = 50, batch_size = 1, verbose = 1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 523
#
# =================================================================
# Total params: 523
# Trainable params: 523
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1304/1304 [==============================] - 2s 847us/step - loss: 116.2811 - root_mean_squared_error: 8.2136
# Epoch 2/50
# 1304/1304 [==============================] - 1s 883us/step - loss: 90.5839 - root_mean_squared_error: 7.2966
# Epoch 3/50
# 1304/1304 [==============================] - 1s 850us/step - loss: 80.3729 - root_mean_squared_error: 6.6873
# Epoch 4/50
# 1304/1304 [==============================] - 1s 881us/step - loss: 71.3729 - root_mean_squared_error: 6.1357
# Epoch 5/50
# 1304/1304 [==============================] - 1s 880us/step - loss: 63.5728 - root_mean_squared_error: 5.6036
# Epoch 6/50
# 1304/1304 [==============================] - 1s 884us/step - loss: 56.7810 - root_mean_squared_error: 5.1253
# Epoch 7/50
# 1304/1304 [==============================] - 1s 876us/step - loss: 51.2371 - root_mean_squared_error: 4.6553
# Epoch 8/50
# 1304/1304 [==============================] - 1s 868us/step - loss: 45.9771 - root_mean_squared_error: 4.2213
# Epoch 9/50
# 1304/1304 [==============================] - 1s 874us/step - loss: 41.5047 - root_mean_squared_error: 3.8174
# Epoch 10/50
# 1304/1304 [==============================] - 1s 843us/step - loss: 37.4688 - root_mean_squared_error: 3.4195
# Epoch 11/50
# 1304/1304 [==============================] - 1s 841us/step - loss: 33.9526 - root_mean_squared_error: 3.0567
# Epoch 12/50
# 1304/1304 [==============================] - 1s 835us/step - loss: 30.7526 - root_mean_squared_error: 2.7159
# Epoch 13/50
# 1304/1304 [==============================] - 1s 856us/step - loss: 27.9200 - root_mean_squared_error: 2.4085
# Epoch 14/50
# 1304/1304 [==============================] - 1s 872us/step - loss: 25.2768 - root_mean_squared_error: 2.1139
# Epoch 15/50
# 1304/1304 [==============================] - 1s 870us/step - loss: 23.4036 - root_mean_squared_error: 1.8444
# Epoch 16/50
# 1304/1304 [==============================] - 1s 873us/step - loss: 20.9297 - root_mean_squared_error: 1.5911
# Epoch 17/50
# 1304/1304 [==============================] - 1s 887us/step - loss: 19.7504 - root_mean_squared_error: 1.3893
# Epoch 18/50
# 1304/1304 [==============================] - 1s 882us/step - loss: 18.2353 - root_mean_squared_error: 1.2066
# Epoch 19/50
# 1304/1304 [==============================] - 1s 871us/step - loss: 17.4130 - root_mean_squared_error: 1.0678
# Epoch 20/50
# 1304/1304 [==============================] - 1s 879us/step - loss: 16.4248 - root_mean_squared_error: 0.9259
# Epoch 21/50
# 1304/1304 [==============================] - 1s 822us/step - loss: 16.0580 - root_mean_squared_error: 0.8487
# Epoch 22/50
# 1304/1304 [==============================] - 1s 889us/step - loss: 15.7994 - root_mean_squared_error: 0.7900
# Epoch 23/50
# 1304/1304 [==============================] - 1s 885us/step - loss: 15.4149 - root_mean_squared_error: 0.7461
# Epoch 24/50
# 1304/1304 [==============================] - 1s 866us/step - loss: 15.3243 - root_mean_squared_error: 0.7266
# Epoch 25/50
# 1304/1304 [==============================] - 1s 882us/step - loss: 15.1693 - root_mean_squared_error: 0.7143
# Epoch 26/50
# 1304/1304 [==============================] - 1s 855us/step - loss: 15.2563 - root_mean_squared_error: 0.7221
# Epoch 27/50
# 1304/1304 [==============================] - 1s 875us/step - loss: 15.0750 - root_mean_squared_error: 0.7224
# Epoch 28/50
# 1304/1304 [==============================] - 1s 870us/step - loss: 15.4851 - root_mean_squared_error: 0.7205
# Epoch 29/50
# 1304/1304 [==============================] - 1s 873us/step - loss: 15.0992 - root_mean_squared_error: 0.7123
# Epoch 30/50
# 1304/1304 [==============================] - 1s 878us/step - loss: 15.1513 - root_mean_squared_error: 0.7210
# Epoch 31/50
# 1304/1304 [==============================] - 1s 820us/step - loss: 15.0011 - root_mean_squared_error: 0.7113
# Epoch 32/50
# 1304/1304 [==============================] - 1s 820us/step - loss: 15.0975 - root_mean_squared_error: 0.7113
# Epoch 33/50
# 1304/1304 [==============================] - 1s 829us/step - loss: 14.8930 - root_mean_squared_error: 0.7213
# Epoch 34/50
# 1304/1304 [==============================] - 1s 818us/step - loss: 15.1360 - root_mean_squared_error: 0.7107
# Epoch 35/50
# 1304/1304 [==============================] - 1s 826us/step - loss: 14.8848 - root_mean_squared_error: 0.7113
# Epoch 36/50
# 1304/1304 [==============================] - 1s 853us/step - loss: 15.1678 - root_mean_squared_error: 0.7311
# Epoch 37/50
# 1304/1304 [==============================] - 1s 854us/step - loss: 14.7572 - root_mean_squared_error: 0.6976
# Epoch 38/50
# 1304/1304 [==============================] - 1s 815us/step - loss: 15.1886 - root_mean_squared_error: 0.7239
# Epoch 39/50
# 1304/1304 [==============================] - 1s 824us/step - loss: 14.8546 - root_mean_squared_error: 0.6964
# Epoch 40/50
# 1304/1304 [==============================] - 1s 843us/step - loss: 15.1202 - root_mean_squared_error: 0.7015
# Epoch 41/50
# 1304/1304 [==============================] - 1s 825us/step - loss: 14.7242 - root_mean_squared_error: 0.7042
# Epoch 42/50
# 1304/1304 [==============================] - 1s 822us/step - loss: 15.1167 - root_mean_squared_error: 0.6982
# Epoch 43/50
# 1304/1304 [==============================] - 1s 818us/step - loss: 14.8633 - root_mean_squared_error: 0.6993
# Epoch 44/50
# 1304/1304 [==============================] - 1s 819us/step - loss: 15.1241 - root_mean_squared_error: 0.7206
# Epoch 45/50
# 1304/1304 [==============================] - 1s 825us/step - loss: 14.9381 - root_mean_squared_error: 0.6961
# Epoch 46/50
# 1304/1304 [==============================] - 1s 816us/step - loss: 14.9476 - root_mean_squared_error: 0.6961
# Epoch 47/50
# 1304/1304 [==============================] - 1s 819us/step - loss: 14.9105 - root_mean_squared_error: 0.7008
# Epoch 48/50
# 1304/1304 [==============================] - 1s 843us/step - loss: 14.8594 - root_mean_squared_error: 0.6974
# Epoch 49/50
# 1304/1304 [==============================] - 1s 821us/step - loss: 14.7048 - root_mean_squared_error: 0.7047
# Epoch 50/50
# 1304/1304 [==============================] - 1s 820us/step - loss: 15.0437 - root_mean_squared_error: 0.7027

# %%
true_pred_plot(ytrain, np.array(model1.predict(xtrain)).reshape(-1,1), ytest, np.array(model1.predict(xtest)).reshape(-1,1))
# Out:
# 41/41 [==============================] - 0s 701us/step
# 11/11 [==============================] - 0s 800us/step
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
model2 = keras.Sequential(
    [
        layers.Dense(xtrain.shape[1], activation="selu", name="layer1", input_shape=(xtrain.shape[1],), input_dim = 2),
        layers.Dense(287, activation="selu", name="layer2"),
        layers.Dense(1, activation = 'linear', name="layer3"),
    ]
)

model2.compile(metrics = [tf.keras.metrics.RootMeanSquaredError()], loss = 'mean_absolute_percentage_error', optimizer = 'adam')

model2.summary()

history2 = model2.fit(xtrain, ytrain, epochs = 50, batch_size = 1, verbose = 1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 522)               273006
#
#  layer2 (Dense)              (None, 287)               150101
#
#  layer3 (Dense)              (None, 1)                 288
#
# =================================================================
# Total params: 423,395
# Trainable params: 423,395
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 60.4403 - root_mean_squared_error: 3.4524
# Epoch 2/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 31.1466 - root_mean_squared_error: 1.5492
# Epoch 3/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 26.8610 - root_mean_squared_error: 1.3303
# Epoch 4/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 25.9636 - root_mean_squared_error: 1.2682
# Epoch 5/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 24.2616 - root_mean_squared_error: 1.2367
# Epoch 6/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 23.9185 - root_mean_squared_error: 1.1962
# Epoch 7/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 21.0788 - root_mean_squared_error: 1.0887
# Epoch 8/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 20.5721 - root_mean_squared_error: 1.0582
# Epoch 9/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 19.1694 - root_mean_squared_error: 0.9565
# Epoch 10/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 19.0287 - root_mean_squared_error: 0.9147
# Epoch 11/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 19.0435 - root_mean_squared_error: 0.9569
# Epoch 12/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 18.0936 - root_mean_squared_error: 0.8434
# Epoch 13/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 18.3999 - root_mean_squared_error: 0.8453
# Epoch 14/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 17.5982 - root_mean_squared_error: 0.8360
# Epoch 15/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 17.7266 - root_mean_squared_error: 0.8156
# Epoch 16/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 17.8502 - root_mean_squared_error: 0.8508
# Epoch 17/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.9317 - root_mean_squared_error: 0.7599
# Epoch 18/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 17.0337 - root_mean_squared_error: 0.7813
# Epoch 19/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.1330 - root_mean_squared_error: 0.7486
# Epoch 20/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.0341 - root_mean_squared_error: 0.7530
# Epoch 21/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.8779 - root_mean_squared_error: 0.7684
# Epoch 22/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.7074 - root_mean_squared_error: 0.7430
# Epoch 23/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.5724 - root_mean_squared_error: 0.8224
# Epoch 24/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.7768 - root_mean_squared_error: 0.7178
# Epoch 25/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.8861 - root_mean_squared_error: 0.7607
# Epoch 26/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.7073 - root_mean_squared_error: 0.6908
# Epoch 27/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.5295 - root_mean_squared_error: 0.6984
# Epoch 28/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.0169 - root_mean_squared_error: 0.7856
# Epoch 29/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.6547 - root_mean_squared_error: 0.7453
# Epoch 30/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.1642 - root_mean_squared_error: 0.6952
# Epoch 31/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.9634 - root_mean_squared_error: 0.7162
# Epoch 32/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.0935 - root_mean_squared_error: 0.6875
# Epoch 33/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.6519 - root_mean_squared_error: 0.6653
# Epoch 34/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.1505 - root_mean_squared_error: 0.7125
# Epoch 35/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.0355 - root_mean_squared_error: 0.6893
# Epoch 36/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.0606 - root_mean_squared_error: 0.6900
# Epoch 37/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.5063 - root_mean_squared_error: 0.7052
# Epoch 38/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.3711 - root_mean_squared_error: 0.6878
# Epoch 39/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.1831 - root_mean_squared_error: 0.6823
# Epoch 40/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.7468 - root_mean_squared_error: 0.6902
# Epoch 41/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.6303 - root_mean_squared_error: 0.6978
# Epoch 42/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.3042 - root_mean_squared_error: 0.7241
# Epoch 43/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.9818 - root_mean_squared_error: 0.7468
# Epoch 44/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.8911 - root_mean_squared_error: 0.6771
# Epoch 45/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.6763 - root_mean_squared_error: 0.7211
# Epoch 46/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.1560 - root_mean_squared_error: 0.6929
# Epoch 47/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.2041 - root_mean_squared_error: 0.6649
# Epoch 48/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.4792 - root_mean_squared_error: 0.6706
# Epoch 49/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.4218 - root_mean_squared_error: 0.7535
# Epoch 50/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.5706 - root_mean_squared_error: 0.6521

# %%
true_pred_plot(ytrain, model2.predict(xtrain), ytest, model2.predict(xtest))
# Out:
# 41/41 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
#now with a multi layer network

model3 = keras.Sequential(
    [
        layers.Dense(xtrain.shape[1], activation="selu", name="layer1", input_shape=(xtrain.shape[1],), input_dim = 2),
        layers.Dense(383, activation="selu", name="layer2a"),
        layers.Dense(287, activation="selu", name="layer2"),
        layers.Dense(82, activation="selu", name="layer3"),
        layers.Dense(20, activation="selu", name="layer4"),
        layers.Dense(1, activation = 'linear', name="layer6"),
    ]
)

model3.compile(metrics = [tf.keras.metrics.RootMeanSquaredError()], loss = 'mean_absolute_percentage_error', optimizer = 'adam')

model3.summary()

history3 = model3.fit(xtrain, ytrain, epochs = 50, batch_size = 1, verbose = 1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 522)               273006
#
#  layer2a (Dense)             (None, 383)               200309
#
#  layer2 (Dense)              (None, 287)               110208
#
#  layer3 (Dense)              (None, 82)                23616
#
#  layer4 (Dense)              (None, 20)                1660
#
#  layer6 (Dense)              (None, 1)                 21
#
# =================================================================
# Total params: 608,820
# Trainable params: 608,820
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 49.2870 - root_mean_squared_error: 2.7585
# Epoch 2/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 23.1882 - root_mean_squared_error: 1.1875
# Epoch 3/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 18.6783 - root_mean_squared_error: 0.8782
# Epoch 4/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 18.5557 - root_mean_squared_error: 0.9004
# Epoch 5/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 17.3192 - root_mean_squared_error: 0.8271
# Epoch 6/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 15.8341 - root_mean_squared_error: 0.7161
# Epoch 7/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 15.2440 - root_mean_squared_error: 0.6971
# Epoch 8/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 14.2884 - root_mean_squared_error: 0.6589
# Epoch 9/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 14.0262 - root_mean_squared_error: 0.6386
# Epoch 10/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 14.2483 - root_mean_squared_error: 0.7181
# Epoch 11/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 14.4268 - root_mean_squared_error: 0.7491
# Epoch 12/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 13.5595 - root_mean_squared_error: 0.6153
# Epoch 13/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 13.1411 - root_mean_squared_error: 0.5999
# Epoch 14/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 13.8566 - root_mean_squared_error: 0.8341
# Epoch 15/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 13.3137 - root_mean_squared_error: 0.6071
# Epoch 16/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 12.9230 - root_mean_squared_error: 0.6183
# Epoch 17/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 49.8378 - root_mean_squared_error: 22.8902
# Epoch 18/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 21.0523 - root_mean_squared_error: 7.5405
# Epoch 19/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 12.2026 - root_mean_squared_error: 0.6005
# Epoch 20/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 12.0611 - root_mean_squared_error: 0.5888
# Epoch 21/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 14.3799 - root_mean_squared_error: 3.4210
# Epoch 22/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 12.4179 - root_mean_squared_error: 0.7047
# Epoch 23/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 14.4042 - root_mean_squared_error: 2.1583
# Epoch 24/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 11.9496 - root_mean_squared_error: 0.5998
# Epoch 25/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 11.9045 - root_mean_squared_error: 0.5695
# Epoch 26/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 11.5631 - root_mean_squared_error: 0.5519
# Epoch 27/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 11.8194 - root_mean_squared_error: 0.5717
# Epoch 28/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 74.2610 - root_mean_squared_error: 38.7376
# Epoch 29/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 33.1530 - root_mean_squared_error: 19.8538
# Epoch 30/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 13.0610 - root_mean_squared_error: 1.3408
# Epoch 31/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 15.2038 - root_mean_squared_error: 4.7071
# Epoch 32/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 11.3715 - root_mean_squared_error: 0.5366
# Epoch 33/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 11.4477 - root_mean_squared_error: 0.5521
# Epoch 34/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 11.2096 - root_mean_squared_error: 0.5563
# Epoch 35/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 13.1142 - root_mean_squared_error: 1.4984
# Epoch 36/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 11.0901 - root_mean_squared_error: 0.5312
# Epoch 37/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 10.9029 - root_mean_squared_error: 0.5249
# Epoch 38/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 11.6042 - root_mean_squared_error: 0.5471
# Epoch 39/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 14.1942 - root_mean_squared_error: 2.6602
# Epoch 40/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 10.7406 - root_mean_squared_error: 0.5119
# Epoch 41/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 12.5503 - root_mean_squared_error: 2.1648
# Epoch 42/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 12.3894 - root_mean_squared_error: 0.9858
# Epoch 43/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 10.0992 - root_mean_squared_error: 0.4944
# Epoch 44/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 10.3641 - root_mean_squared_error: 0.4978
# Epoch 45/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 10.2431 - root_mean_squared_error: 0.5068
# Epoch 46/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 10.6476 - root_mean_squared_error: 0.5161
# Epoch 47/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 26.8253 - root_mean_squared_error: 18.4923
# Epoch 48/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 10.8152 - root_mean_squared_error: 0.4945
# Epoch 49/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 10.6360 - root_mean_squared_error: 1.1768
# Epoch 50/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 9.8192 - root_mean_squared_error: 0.4836

# %%
true_pred_plot(ytrain, model3.predict(xtrain), ytest, model3.predict(xtest))
# Out:
# 41/41 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
from sklearn.ensemble import RandomForestRegressor

n_grid = {'n_estimators' : list(np.arange(50,550,50))}
score = 'r2'

rfr_grid = GridSearchCV(RandomForestRegressor(), n_grid, cv =3, scoring = score, verbose = 1)

rfr_grid.fit(xtrain, ytrain)

print('Best params on training set : {}'.format(rfr_grid.best_params_))

    
model_rfr = RandomForestRegressor(n_estimators=rfr_grid.best_params_['n_estimators'], verbose = 1).fit(xtrain, ytrain)

true_pred_plot(ytrain, model_rfr.predict(xtrain), ytest, model_rfr.predict(xtest))
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best params on training set : {'n_estimators': 400}
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    8.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.0s finished
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
from sklearn.ensemble import GradientBoostingRegressor

n_grid = {'n_estimators' : list(np.arange(50,550,50))}
score = 'r2'

xgb_grid = GridSearchCV(RandomForestRegressor(), n_grid, cv =3, scoring = score, verbose = 1)

xgb_grid.fit(xtrain, ytrain)

print('Best params on training set : {}'.format(xgb_grid.best_params_))

    
model_xgb = RandomForestRegressor(n_estimators=xgb_grid.best_params_['n_estimators'], verbose = 1).fit(xtrain, ytrain)

true_pred_plot(ytrain, model_xgb.predict(xtrain), ytest, model_xgb.predict(xtest))
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best params on training set : {'n_estimators': 350}
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 350 out of 350 | elapsed:    7.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 350 out of 350 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 350 out of 350 | elapsed:    0.0s finished
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
def r2(pred,y):
    pred = np.array(pred).reshape(-1,1)
    y = np.array(y).reshape(-1,1)
    
    pred = pred*sqftest
    y = y*sqftest
    
    line_reg_test  = line_reg.fit(pred,y)
    r2_value =  line_reg_test.score(pred,y)
    return r2_value

def rmse(pred,y):
    pred = np.array(pred).reshape(-1,1)
    y = np.array(y).reshape(-1,1)
    
    pred = pred*sqftest
    y = y*sqftest
    
    rmse_value = np.sqrt(metrics.mean_squared_error(y,pred))
    return rmse_value

def nrmse(pred,y):
    pred = np.array(pred).reshape(-1,1)
    y = np.array(y).reshape(-1,1)
    
    pred = pred*sqftest
    y = y*sqftest
    
    nrmse_value = (np.sqrt(metrics.mean_squared_error(y,pred))/np.mean(y))
    return nrmse_value
                   
def mae(pred,y):
    pred = np.array(pred).reshape(-1,1)
    y = np.array(y).reshape(-1,1)
    
    pred = pred*sqftest
    y = y*sqftest
    
    mae_value = metrics.mean_absolute_error(y,pred)
    return mae_value

# %%
metrics_all = {}

models = [model_kn,svr,model_krr,model3,model_rfr,model_xgb]
r2l=[]
rmsel=[]
nrmsel=[]
mael=[]

for i in models:
    r2l.append(r2(i.predict(xtest),ytest))
    rmsel.append(rmse(i.predict(xtest), ytest))
    nrmsel.append(nrmse(i.predict(xtest), ytest))
    mael.append(mae(i.predict(xtest), ytest))
    
metrics_all['r2'] = r2l
metrics_all['rmse'] = rmsel
metrics_all['nrmse'] = nrmsel
metrics_all['mae'] = mael

model_names = ['KNN_Regressor', 'SVR', 'Kernel_Ridge_Regressor','Neural_Network', 'Random_Forest_Regressor', 'XGBoost']
df_metrics = pd.DataFrame(metrics_all, index = model_names)

fig = plt.figure(figsize=(20, 20))
for i in range(df_metrics.shape[1]):
    ax = fig.add_subplot(2,2, (i+1))
    b = ax.bar(x=df_metrics.index,height = df_metrics.iloc[:, i])
    ax.set_title(df_metrics.columns[i], fontsize=14)
    ax.tick_params(axis='x', labelrotation = 35)
    if i != 0:
        ax.set_yscale('log')
# Out:
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 3ms/step
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 350 out of 350 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 350 out of 350 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 350 out of 350 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 350 out of 350 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:    0.0s finished

# %%
test = [10,20,30,40,50]
test2 = ['a','b','c','d','e']

for i,(v,w) in enumerate(zip(test,test2)):
    print(i,v,w)
# Out:
# 0 10 a
# 1 20 b
# 2 30 c
# 3 40 d
# 4 50 e

# %%
importance = model_xgb.feature_importances_
nul_col = []
for i,v in enumerate(importance):
    if v == 0:
        nul_col.append(i)
nul_col_name = []
for i in nul_col:
    nul_col_name.append(col_name_lib[str(i)])
print(len(nul_col_name))

df_fi = {}
for i,v in enumerate(importance):
    x = col_name_lib[str(i)]
    df_fi[f'{x}'] = v

df_fi = pd.DataFrame(df_fi, index = ['Feature_Importance']).T
print(df_fi['Feature_Importance'].nlargest(10))


# plot feature importance
fig, ax = plt.subplots(figsize = (20,20))
ax.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# 47
# ThirdLargestPropertyUseTypeGFA     0.201290
# Neighborhood_EAST                  0.101369
# PropertyGFABuilding(s)             0.098217
# Neighborhood_DOWNTOWN              0.054795
# SecondLargestPropertyUseTypeGFA    0.053567
# YearBuilt                          0.039232
# Latitude                           0.039173
# Longitude                          0.037143
# Neighborhood_Central               0.027207
# ZipCode                            0.023479
# Name: Feature_Importance, dtype: float64

# %% [markdown]
# ### Etude de l'impact de l'Energy Score

# %%
data_num = df
target_tag = 'SiteEUI(kBtu/sf)'
target = data_num[target_tag]
label = ['TotalGHGEmissions', 'ENERGYSTARScore','SiteEnergyUse(kBtu)', 'GHGEmissionsIntensity']
sqf = data_num['PropertyGFABuilding(s)']
data_num = data_num.drop(labels = [target_tag, 'TotalGHGEmissions','SiteEnergyUse(kBtu)', 'GHGEmissionsIntensity'], axis = 1)

#first let's test this on knregressoe
xtrain, xtest, ytrain, ytest, sqftrain, sqftest = train_test_split(data_num, target, sqf, test_size = 0.2)

df_res = xtrain

#let's standard scale

sscaler = sk_prepro.StandardScaler()
sscaler_fit = sscaler.fit(xtrain)
xtrain = sscaler_fit.transform(xtrain)
xtest = sscaler_fit.transform(xtest)
#log scale the target
ytrain = np.log(ytrain)
ytest = np.log(ytest)

sqftrain = np.array(sqftrain).reshape(-1,1)
sqftest = np.array(sqftest).reshape(-1,1)
