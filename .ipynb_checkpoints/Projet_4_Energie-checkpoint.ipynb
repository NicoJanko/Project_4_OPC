# %% [markdown]
# # Modelisation de la consommation totale d'energie

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
import sklearn.preprocessing as sk_prepro
from sklearn import metrics

# %%
df = pd.read_csv('data_full.csv')

# %%
rand = int(np.random.randint(100))

# %%
data_num = df
target_tag = 'SiteEUI(kBtu/sf)'
target = data_num[target_tag]
label = ['TotalGHGEmissions', 'ENERGYSTARScore','SiteEnergyUse(kBtu)', 'GHGEmissionsIntensity']
sqf = data_num['PropertyGFABuilding(s)']
data_num = data_num.drop(labels = [target_tag, 'TotalGHGEmissions', 'ENERGYSTARScore','SiteEnergyUse(kBtu)', 'GHGEmissionsIntensity'], axis = 1)

col_name_lib = {}
col_name = data_num.columns
for i,v in enumerate(col_name):
    col_name_lib[f'{i}'] = v

# %%
data_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1630 entries, 0 to 1629
# Columns: 522 entries, BuildingType_Campus to ThirdLargestPropertyUseTypeGFA
# dtypes: float64(522)
# memory usage: 6.5 MB

# %% [markdown]
# ## Modèle linéaire

# %%
from sklearn.linear_model import Ridge
from sklearn import svm
from sklearn.neighbors import KNeighborsRegressor

# %%
#first let's split

xtrain, xtest, ytrain, ytest, sqftrain, sqftest = train_test_split(data_num, target, sqf, test_size = 0.2, random_state = rand)

df_res = xtest
df_res_train = xtrain
#let's standard scale

sscaler = sk_prepro.StandardScaler()
sscaler_fit = sscaler.fit(xtrain)
xtrain = sscaler_fit.transform(xtrain)
xtest = sscaler_fit.transform(xtest)
#log scale the target
ytrain = np.log(ytrain)
ytest = np.log(ytest)

sqftrain = np.array(sqftrain).reshape(-1,1)
sqftest = np.array(sqftest).reshape(-1,1)

# %%
from sklearn import linear_model
line_reg = linear_model.LinearRegression()

# %%
def true_pred_plot(y_train,pred_train, y_test, pred_test, figname):
    fig, ax = plt.subplots(2, figsize = (10,10))
    
    y_train= np.array(y_train).reshape(-1,1)
    pred_train = np.array(pred_train).reshape(-1,1)
    y_test = np.array(y_test).reshape(-1,1)
    pred_test = np.array(pred_test).reshape(-1,1)
    
    
    
    y_train = y_train*sqftrain
    pred_train = pred_train*sqftrain
    
    line_reg_train = line_reg.fit(pred_train,y_train)
    r2_train = line_reg_train.score(pred_train,y_train)
    rmse_train = (np.sqrt(metrics.mean_squared_error(y_train, pred_train))/np.mean(y_train))
    a = float(line_reg_train.coef_)
    b= line_reg_train.intercept_
    ax[0].scatter( y_train, pred_train)
    ax[0].plot([a*np.abs(b)+b, a*y_train.max()+b],[np.abs(b), y_train.max()], linestyle = 'dashed')
    ax[0].text(0.7,0.4,'R2 : {:.3f} NRMSE : {: .2f}'.format(r2_train,rmse_train), transform = ax[0].transAxes)
    ax[0].set_xlabel('True values')
    ax[0].set_ylabel('Predicted values')
    ax[0].set_xlim(y_train.min(),y_train.max())
    ax[0].set_ylim(pred_train.min(),pred_train.max())
    ax[0].set_title('On train values')

    y_test = y_test*sqftest
    pred_test = pred_test*sqftest
    
    line_reg_test  = line_reg.fit(pred_test,y_test)
    r2_test =  line_reg_test.score(pred_test,y_test)
    rmse_test = (np.sqrt(metrics.mean_squared_error(y_test, pred_test))/np.mean(y_test))
    a = float(line_reg_test.coef_)
    b=  line_reg_test.intercept_
    ax[1].scatter( y_test, pred_test)
    ax[1].plot([a*np.abs(b)+b, a*y_test.max()+b],[np.abs(b), y_test.max()], linestyle = 'dashed')
    ax[1].text(0.7,0.4,'R2 : {:.3f} NRMSE : {: .2f}'.format(r2_test, rmse_test), transform = ax[1].transAxes)
    ax[1].set_xlabel('True values')
    ax[1].set_ylabel('Predicted values')
    ax[1].set_xlim(y_test.min(),y_test.max())
    ax[1].set_ylim(pred_test.min(),pred_test.max())
    ax[1].set_title('On test values')
    
    plt.show()
    plt.savefig(figname, bbox_inches = 'tight')
    plt.clf()

# %%
x = input('Do you want to launch ? [y/n]')
if x == 'y':

    line_reg_m = linear_model.LinearRegression()

    model_lr = line_reg_m.fit(xtrain,ytrain)


    true_pred_plot(ytrain, model_lr.predict(xtrain), ytest, model_lr.predict(xtest),'line_reg_ery.png')
# Out:
# Do you want to launch ? [y/n] y
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
#let's grid search for the k

k_grid = {'n_neighbors' : list(range(2,16))}
score = 'r2'

reg = GridSearchCV(KNeighborsRegressor(), k_grid, cv =3, scoring = score, verbose = 1)

reg.fit(xtrain, ytrain)

print('Best params on training set : {}'.format(reg.best_params_))

print('GridCV results : ')
for mean, std, k in zip(reg.cv_results_['mean_test_score'],
                       reg.cv_results_['std_test_score'],
                       reg.cv_results_['params']):
    print('{} = {:.3f} (+/- {:.3f}) for {}'.format(score,mean,std*2,k))
    
model_kn = KNeighborsRegressor(n_neighbors = reg.best_params_['n_neighbors']).fit(xtrain, ytrain)

true_pred_plot(ytrain, model_kn.predict(xtrain), ytest, model_kn.predict(xtest),'knn_ergy.png')
# Out:
# Fitting 3 folds for each of 14 candidates, totalling 42 fits
# Best params on training set : {'n_neighbors': 5}
# GridCV results :
# r2 = 0.155 (+/- 0.187) for {'n_neighbors': 2}
# r2 = 0.226 (+/- 0.159) for {'n_neighbors': 3}
# r2 = 0.241 (+/- 0.109) for {'n_neighbors': 4}
# r2 = 0.258 (+/- 0.090) for {'n_neighbors': 5}
# r2 = 0.255 (+/- 0.053) for {'n_neighbors': 6}
# r2 = 0.246 (+/- 0.052) for {'n_neighbors': 7}
# r2 = 0.241 (+/- 0.061) for {'n_neighbors': 8}
# r2 = 0.242 (+/- 0.067) for {'n_neighbors': 9}
# r2 = 0.240 (+/- 0.069) for {'n_neighbors': 10}
# r2 = 0.246 (+/- 0.069) for {'n_neighbors': 11}
# r2 = 0.245 (+/- 0.059) for {'n_neighbors': 12}
# r2 = 0.245 (+/- 0.054) for {'n_neighbors': 13}
# r2 = 0.243 (+/- 0.054) for {'n_neighbors': 14}
# r2 = 0.240 (+/- 0.061) for {'n_neighbors': 15}
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
x = input('Do you want to launch ? [y/n]')
if x == 'y':

    #let's try with a svr
    C_range = [1.0, 5.0, 10.0, 100.0]
    kernels = ['linear', 'rbf', 'sigmoid', 'poly']
    degrees = [2,3,4]
    gamma_range  = np.logspace(-2, 1, 10)
    #gamma_range = np.logspace(-2, 1, 10)
    #'gamma' : gamma_range
    param_grid = {'gamma' : gamma_range, 'kernel' : kernels, 'degree' : degrees}

    score = 'neg_mean_squared_error'

    svr_cv = GridSearchCV(svm.SVR(), param_grid, cv = 3, scoring = score, verbose = 1)

    svr_cv.fit(xtrain, ytrain)

    print('Best params on training set : {}'.format(svr_cv.best_params_))
bkernel = svr_cv.best_params_['kernel']
bgamma = svr_cv.best_params_['gamma']
bdegree = svr_cv.best_params_['degree']
    
svr = svm.SVR(kernel=bkernel, C=1.0, gamma = bgamma, degree = bdegree)
model_svr = svr.fit(xtrain,ytrain)

true_pred_plot(ytrain, model_svr.predict(xtrain), ytest, model_svr.predict(xtest),'svr_ergy.png')
# Out:
# Do you want to launch ? [y/n] y
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# Best params on training set : {'degree': 2, 'gamma': 0.01, 'kernel': 'rbf'}
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
from sklearn import kernel_ridge
#let's try with a ridge regression

x = input('Do you want to launch ? [y/n]')
if x == 'y':
    alpha_range = [1.0, 5.0, 10.0, 100.0]
    kernels = ['linear', 'poly', 'rbf']
    degrees = [3,4,5]
    gamma_range  = np.logspace(-2, 1, 10)


    param_grid = {'gamma' : gamma_range, 'kernel' : kernels, 'degree' : degrees, 'alpha' : alpha_range}
    
    score = 'neg_mean_absolute_percentage_error'

    kernel_ridge_cv = GridSearchCV(kernel_ridge.KernelRidge(), param_grid, cv = 3, scoring = score, verbose = 1)

    kernel_ridge_cv.fit(xtrain, ytrain)

    print('Best params on training set : {}'.format(kernel_ridge_cv.best_params_))
    
bkernel = kernel_ridge_cv.best_params_['kernel']
bgamma = kernel_ridge_cv.best_params_['gamma']
bdegree = kernel_ridge_cv.best_params_['degree']
balpha = kernel_ridge_cv.best_params_['alpha']

model = kernel_ridge.KernelRidge(alpha = balpha, kernel = bkernel, degree = bdegree, gamma = bgamma)
model_krr = model.fit(xtrain, ytrain)

true_pred_plot(ytrain, model_krr.predict(xtrain), ytest, model_krr.predict(xtest),'krr_ergy.png')
# Out:
# Do you want to launch ? [y/n] y
# Fitting 3 folds for each of 360 candidates, totalling 1080 fits
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=8.33877e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.4994e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.28035e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.20313e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.16802e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.71565e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.285e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.20323e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.16803e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.98653e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.29082e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.20336e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.16803e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.09348e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.39563e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.20561e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# E:\Data_Science\Anaconda\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.16808e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Best params on training set : {'alpha': 1.0, 'degree': 3, 'gamma': 0.01, 'kernel': 'poly'}
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %% [markdown]
# ## Neural network

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
#test with a single perceptron
model1 = keras.Sequential()
model1.add(keras.Input(shape = xtrain.shape[1]))
model1.add(layers.Dense(1,input_dim = 2, activation = 'linear'))

model1.compile(metrics = [tf.keras.metrics.RootMeanSquaredError()], loss = 'mean_absolute_percentage_error', optimizer = 'adam')

model1.summary()

history1 = model1.fit(xtrain, ytrain, epochs = 50, batch_size = 1, verbose = 1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 523
#
# =================================================================
# Total params: 523
# Trainable params: 523
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1304/1304 [==============================] - 2s 1ms/step - loss: 120.6411 - root_mean_squared_error: 8.7414
# Epoch 2/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 93.0363 - root_mean_squared_error: 7.7709
# Epoch 3/50
# 1304/1304 [==============================] - 1s 980us/step - loss: 83.1465 - root_mean_squared_error: 7.2054
# Epoch 4/50
# 1304/1304 [==============================] - 1s 972us/step - loss: 74.6321 - root_mean_squared_error: 6.6614
# Epoch 5/50
# 1304/1304 [==============================] - 1s 972us/step - loss: 67.6668 - root_mean_squared_error: 6.1619
# Epoch 6/50
# 1304/1304 [==============================] - 1s 969us/step - loss: 61.2715 - root_mean_squared_error: 5.6666
# Epoch 7/50
# 1304/1304 [==============================] - 1s 965us/step - loss: 55.4769 - root_mean_squared_error: 5.2069
# Epoch 8/50
# 1304/1304 [==============================] - 1s 994us/step - loss: 50.5019 - root_mean_squared_error: 4.7626
# Epoch 9/50
# 1304/1304 [==============================] - 1s 970us/step - loss: 45.6679 - root_mean_squared_error: 4.3320
# Epoch 10/50
# 1304/1304 [==============================] - 1s 982us/step - loss: 41.7050 - root_mean_squared_error: 3.9251
# Epoch 11/50
# 1304/1304 [==============================] - 1s 957us/step - loss: 37.4877 - root_mean_squared_error: 3.5114
# Epoch 12/50
# 1304/1304 [==============================] - 1s 980us/step - loss: 34.0601 - root_mean_squared_error: 3.1433
# Epoch 13/50
# 1304/1304 [==============================] - 1s 985us/step - loss: 30.4659 - root_mean_squared_error: 2.7866
# Epoch 14/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 27.9122 - root_mean_squared_error: 2.4495
# Epoch 15/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 25.1257 - root_mean_squared_error: 2.1374
# Epoch 16/50
# 1304/1304 [==============================] - 1s 981us/step - loss: 22.9911 - root_mean_squared_error: 1.8420
# Epoch 17/50
# 1304/1304 [==============================] - 1s 975us/step - loss: 20.8799 - root_mean_squared_error: 1.5808
# Epoch 18/50
# 1304/1304 [==============================] - 1s 958us/step - loss: 19.2574 - root_mean_squared_error: 1.3594
# Epoch 19/50
# 1304/1304 [==============================] - 1s 971us/step - loss: 18.0416 - root_mean_squared_error: 1.1634
# Epoch 20/50
# 1304/1304 [==============================] - 1s 982us/step - loss: 16.7105 - root_mean_squared_error: 1.0118
# Epoch 21/50
# 1304/1304 [==============================] - 1s 999us/step - loss: 16.3303 - root_mean_squared_error: 0.8791
# Epoch 22/50
# 1304/1304 [==============================] - 1s 966us/step - loss: 15.6111 - root_mean_squared_error: 0.7928
# Epoch 23/50
# 1304/1304 [==============================] - 1s 985us/step - loss: 15.1530 - root_mean_squared_error: 0.7458
# Epoch 24/50
# 1304/1304 [==============================] - 1s 973us/step - loss: 15.0042 - root_mean_squared_error: 0.7112
# Epoch 25/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 14.9046 - root_mean_squared_error: 0.6991
# Epoch 26/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 14.8876 - root_mean_squared_error: 0.6822
# Epoch 27/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 14.6801 - root_mean_squared_error: 0.6835
# Epoch 28/50
# 1304/1304 [==============================] - 1s 967us/step - loss: 14.8139 - root_mean_squared_error: 0.6945
# Epoch 29/50
# 1304/1304 [==============================] - 1s 975us/step - loss: 14.7545 - root_mean_squared_error: 0.6861
# Epoch 30/50
# 1304/1304 [==============================] - 1s 989us/step - loss: 14.6387 - root_mean_squared_error: 0.6811
# Epoch 31/50
# 1304/1304 [==============================] - 1s 969us/step - loss: 14.6675 - root_mean_squared_error: 0.6858
# Epoch 32/50
# 1304/1304 [==============================] - 1s 962us/step - loss: 14.5275 - root_mean_squared_error: 0.6880
# Epoch 33/50
# 1304/1304 [==============================] - 1s 972us/step - loss: 14.7149 - root_mean_squared_error: 0.7028
# Epoch 34/50
# 1304/1304 [==============================] - 1s 965us/step - loss: 14.6179 - root_mean_squared_error: 0.6965
# Epoch 35/50
# 1304/1304 [==============================] - 1s 967us/step - loss: 14.8789 - root_mean_squared_error: 0.7085
# Epoch 36/50
# 1304/1304 [==============================] - 1s 991us/step - loss: 14.5180 - root_mean_squared_error: 0.6810
# Epoch 37/50
# 1304/1304 [==============================] - 1s 985us/step - loss: 14.6458 - root_mean_squared_error: 0.6829
# Epoch 38/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 14.6989 - root_mean_squared_error: 0.6792
# Epoch 39/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 14.5907 - root_mean_squared_error: 0.6840
# Epoch 40/50
# 1304/1304 [==============================] - 1s 974us/step - loss: 14.6849 - root_mean_squared_error: 0.6936
# Epoch 41/50
# 1304/1304 [==============================] - 1s 961us/step - loss: 14.5406 - root_mean_squared_error: 0.6719
# Epoch 42/50
# 1304/1304 [==============================] - 1s 997us/step - loss: 14.6705 - root_mean_squared_error: 0.6803
# Epoch 43/50
# 1304/1304 [==============================] - 1s 980us/step - loss: 14.5011 - root_mean_squared_error: 0.6771
# Epoch 44/50
# 1304/1304 [==============================] - 1s 955us/step - loss: 14.7356 - root_mean_squared_error: 0.6753
# Epoch 45/50
# 1304/1304 [==============================] - 1s 964us/step - loss: 14.5613 - root_mean_squared_error: 0.6875
# Epoch 46/50
# 1304/1304 [==============================] - 1s 965us/step - loss: 14.7123 - root_mean_squared_error: 0.6862
# Epoch 47/50
# 1304/1304 [==============================] - 1s 973us/step - loss: 14.1620 - root_mean_squared_error: 0.6805
# Epoch 48/50
# 1304/1304 [==============================] - 1s 964us/step - loss: 14.6895 - root_mean_squared_error: 0.6795
# Epoch 49/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 14.2884 - root_mean_squared_error: 0.6813
# Epoch 50/50
# 1304/1304 [==============================] - 1s 980us/step - loss: 14.4366 - root_mean_squared_error: 0.6679

# %%
true_pred_plot(ytrain, np.array(model1.predict(xtrain)).reshape(-1,1), ytest, np.array(model1.predict(xtest)).reshape(-1,1),'perce_ergy.png')
# Out:
# 41/41 [==============================] - 0s 900us/step
# 11/11 [==============================] - 0s 1000us/step
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
model2 = keras.Sequential(
    [
        layers.Dense(xtrain.shape[1], activation="selu", name="layer1", input_shape=(xtrain.shape[1],), input_dim = 2),
        layers.Dense(287, activation="selu", name="layer2"),
        layers.Dense(1, activation = 'linear', name="layer3"),
    ]
)

model2.compile(metrics = [tf.keras.metrics.RootMeanSquaredError()], loss = 'mean_absolute_percentage_error', optimizer = 'adam')

model2.summary()

history2 = model2.fit(xtrain, ytrain, epochs = 50, batch_size = 1, verbose = 1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 522)               273006
#
#  layer2 (Dense)              (None, 287)               150101
#
#  layer3 (Dense)              (None, 1)                 288
#
# =================================================================
# Total params: 423,395
# Trainable params: 423,395
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 62.1476 - root_mean_squared_error: 3.7113
# Epoch 2/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 29.5649 - root_mean_squared_error: 1.4676
# Epoch 3/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 27.8142 - root_mean_squared_error: 1.4163
# Epoch 4/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 25.9224 - root_mean_squared_error: 1.2802
# Epoch 5/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 24.6895 - root_mean_squared_error: 1.2680
# Epoch 6/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 23.0336 - root_mean_squared_error: 1.1898
# Epoch 7/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 21.1914 - root_mean_squared_error: 1.0063
# Epoch 8/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 18.9744 - root_mean_squared_error: 0.9012
# Epoch 9/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 18.6225 - root_mean_squared_error: 0.8946
# Epoch 10/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 19.2183 - root_mean_squared_error: 0.9019
# Epoch 11/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 18.5157 - root_mean_squared_error: 0.8350
# Epoch 12/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 18.8708 - root_mean_squared_error: 0.8793
# Epoch 13/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 18.3874 - root_mean_squared_error: 0.8723
# Epoch 14/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 17.0834 - root_mean_squared_error: 0.8095
# Epoch 15/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 17.3626 - root_mean_squared_error: 0.8343
# Epoch 16/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 17.3372 - root_mean_squared_error: 0.7895
# Epoch 17/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.5130 - root_mean_squared_error: 0.7579
# Epoch 18/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 17.3131 - root_mean_squared_error: 0.7954
# Epoch 19/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.0795 - root_mean_squared_error: 0.7442
# Epoch 20/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.7675 - root_mean_squared_error: 0.7649
# Epoch 21/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.5356 - root_mean_squared_error: 0.7460
# Epoch 22/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.5937 - root_mean_squared_error: 0.7766
# Epoch 23/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.4529 - root_mean_squared_error: 0.7723
# Epoch 24/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.4563 - root_mean_squared_error: 0.7413
# Epoch 25/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.9608 - root_mean_squared_error: 0.7568
# Epoch 26/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.9159 - root_mean_squared_error: 0.7300
# Epoch 27/50
# 1304/1304 [==============================] - 2s 2ms/step - loss: 15.4333 - root_mean_squared_error: 0.6861
# Epoch 28/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.9064 - root_mean_squared_error: 0.7787
# Epoch 29/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.4676 - root_mean_squared_error: 0.7405
# Epoch 30/50
# 1304/1304 [==============================] - 2s 2ms/step - loss: 15.3973 - root_mean_squared_error: 0.7107
# Epoch 31/50
# 1304/1304 [==============================] - 2s 2ms/step - loss: 14.8685 - root_mean_squared_error: 0.6910
# Epoch 32/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.5696 - root_mean_squared_error: 0.7079
# Epoch 33/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.1112 - root_mean_squared_error: 0.7083
# Epoch 34/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.0649 - root_mean_squared_error: 0.6962
# Epoch 35/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.0481 - root_mean_squared_error: 0.7015
# Epoch 36/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.4782 - root_mean_squared_error: 0.7042
# Epoch 37/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.5449 - root_mean_squared_error: 0.7755
# Epoch 38/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.4121 - root_mean_squared_error: 0.7062
# Epoch 39/50
# 1304/1304 [==============================] - 2s 2ms/step - loss: 15.8595 - root_mean_squared_error: 0.7913
# Epoch 40/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.9680 - root_mean_squared_error: 0.7050
# Epoch 41/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.1223 - root_mean_squared_error: 0.7104
# Epoch 42/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.8365 - root_mean_squared_error: 0.7839
# Epoch 43/50
# 1304/1304 [==============================] - 2s 2ms/step - loss: 14.3543 - root_mean_squared_error: 0.6748
# Epoch 44/50
# 1304/1304 [==============================] - 2s 2ms/step - loss: 15.0958 - root_mean_squared_error: 0.7118
# Epoch 45/50
# 1304/1304 [==============================] - 2s 2ms/step - loss: 15.1265 - root_mean_squared_error: 0.7093
# Epoch 46/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.0573 - root_mean_squared_error: 0.7205
# Epoch 47/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.6393 - root_mean_squared_error: 0.6797
# Epoch 48/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.2151 - root_mean_squared_error: 0.6997
# Epoch 49/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.7775 - root_mean_squared_error: 0.6832
# Epoch 50/50
# 1304/1304 [==============================] - 2s 2ms/step - loss: 14.7190 - root_mean_squared_error: 0.6841

# %%
true_pred_plot(ytrain, model2.predict(xtrain), ytest, model2.predict(xtest))
# Out:
# 41/41 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 true_pred_plot(ytrain, model2.predict(xtrain), ytest, model2.predict(xtest))
#
# TypeError: true_pred_plot() missing 1 required positional argument: 'figname'

# %%
#now with a multi layer network

model3 = keras.Sequential(
    [
        layers.Dense(xtrain.shape[1], activation="selu", name="layer1", input_shape=(xtrain.shape[1],), input_dim = 2),
        layers.Dense(383, activation="selu", name="layer2a"),
        layers.Dense(287, activation="selu", name="layer2"),
        layers.Dense(82, activation="selu", name="layer3"),
        layers.Dense(20, activation="selu", name="layer4"),
        layers.Dense(1, activation = 'linear', name="layer6"),
    ]
)

model3.compile(metrics = [tf.keras.metrics.RootMeanSquaredError()], loss = 'mean_absolute_percentage_error', optimizer = 'adam')

model3.summary()

history3 = model3.fit(xtrain, ytrain, epochs = 50, batch_size = 1, verbose = 1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 522)               273006
#
#  layer2a (Dense)             (None, 383)               200309
#
#  layer2 (Dense)              (None, 287)               110208
#
#  layer3 (Dense)              (None, 82)                23616
#
#  layer4 (Dense)              (None, 20)                1660
#
#  layer6 (Dense)              (None, 1)                 21
#
# =================================================================
# Total params: 608,820
# Trainable params: 608,820
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1304/1304 [==============================] - 4s 2ms/step - loss: 55.9080 - root_mean_squared_error: 3.2495
# Epoch 2/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 29.8764 - root_mean_squared_error: 1.5119
# Epoch 3/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 22.9858 - root_mean_squared_error: 1.1480
# Epoch 4/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 22.0384 - root_mean_squared_error: 1.0875
# Epoch 5/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 19.9147 - root_mean_squared_error: 1.0209
# Epoch 6/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.5617 - root_mean_squared_error: 0.8820
# Epoch 7/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.8207 - root_mean_squared_error: 0.7127
# Epoch 8/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.7447 - root_mean_squared_error: 0.8845
# Epoch 9/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.2791 - root_mean_squared_error: 0.6471
# Epoch 10/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.3893 - root_mean_squared_error: 0.6839
# Epoch 11/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 13.7677 - root_mean_squared_error: 0.6203
# Epoch 12/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.0728 - root_mean_squared_error: 0.7162
# Epoch 13/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 15.6317 - root_mean_squared_error: 3.2742
# Epoch 14/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 13.2553 - root_mean_squared_error: 0.6162
# Epoch 15/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 13.2296 - root_mean_squared_error: 0.6054
# Epoch 16/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 13.4131 - root_mean_squared_error: 0.8008
# Epoch 17/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 12.7478 - root_mean_squared_error: 0.5745
# Epoch 18/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.0366 - root_mean_squared_error: 4.6083
# Epoch 19/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 12.0397 - root_mean_squared_error: 0.5640
# Epoch 20/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.5864 - root_mean_squared_error: 3.9355
# Epoch 21/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 41.2825 - root_mean_squared_error: 36.6202
# Epoch 22/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 12.5892 - root_mean_squared_error: 0.6289
# Epoch 23/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 12.2183 - root_mean_squared_error: 0.5797
# Epoch 24/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 12.9624 - root_mean_squared_error: 1.5535
# Epoch 25/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.7522 - root_mean_squared_error: 0.5533
# Epoch 26/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 17.2876 - root_mean_squared_error: 3.9826
# Epoch 27/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 12.4388 - root_mean_squared_error: 0.6776
# Epoch 28/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.7959 - root_mean_squared_error: 0.5719
# Epoch 29/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.7739 - root_mean_squared_error: 0.5672
# Epoch 30/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.7731 - root_mean_squared_error: 0.6369
# Epoch 31/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.8730 - root_mean_squared_error: 0.5442
# Epoch 32/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.8654 - root_mean_squared_error: 0.5719
# Epoch 33/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.5048 - root_mean_squared_error: 0.5509
# Epoch 34/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 14.9372 - root_mean_squared_error: 4.1263
# Epoch 35/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 113.0936 - root_mean_squared_error: 97.2240
# Epoch 36/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 12.8353 - root_mean_squared_error: 2.3806
# Epoch 37/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.7136 - root_mean_squared_error: 0.5257
# Epoch 38/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.8396 - root_mean_squared_error: 0.5398
# Epoch 39/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.4654 - root_mean_squared_error: 0.5321
# Epoch 40/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.1854 - root_mean_squared_error: 0.4980
# Epoch 41/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.6804 - root_mean_squared_error: 0.5207
# Epoch 42/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.0793 - root_mean_squared_error: 0.7252
# Epoch 43/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.6396 - root_mean_squared_error: 0.5094
# Epoch 44/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.1910 - root_mean_squared_error: 0.8611
# Epoch 45/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.3521 - root_mean_squared_error: 0.4996
# Epoch 46/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.0026 - root_mean_squared_error: 0.8442
# Epoch 47/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.5583 - root_mean_squared_error: 0.5602
# Epoch 48/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 51.2390 - root_mean_squared_error: 40.2464
# Epoch 49/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 9.8814 - root_mean_squared_error: 0.4789
# Epoch 50/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 10.6994 - root_mean_squared_error: 1.6340

# %%
true_pred_plot(ytrain, model3.predict(xtrain), ytest, model3.predict(xtest), 'model3_ergy.png')
# Out:
# 41/41 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
from sklearn.ensemble import RandomForestRegressor

n_grid = {'n_estimators' : list(np.arange(50,550,50))}
score = 'r2'

rfr_grid = GridSearchCV(RandomForestRegressor(), n_grid, cv =3, scoring = score, verbose = 1)

rfr_grid.fit(xtrain, ytrain)

print('Best params on training set : {}'.format(rfr_grid.best_params_))

    
model_rfr = RandomForestRegressor(n_estimators=rfr_grid.best_params_['n_estimators'], verbose = 1).fit(xtrain, ytrain)

true_pred_plot(ytrain, model_rfr.predict(xtrain), ytest, model_rfr.predict(xtest),'rfr_ergy.png')
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best params on training set : {'n_estimators': 450}
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 450 out of 450 | elapsed:   10.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 450 out of 450 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 450 out of 450 | elapsed:    0.0s finished
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
from sklearn.ensemble import GradientBoostingRegressor

n_grid = {'n_estimators' : list(np.arange(50,550,50))}
score = 'r2'

xgb_grid = GridSearchCV(GradientBoostingRegressor(), n_grid, cv =3, scoring = score, verbose = 1)

xgb_grid.fit(xtrain, ytrain)

print('Best params on training set : {}'.format(xgb_grid.best_params_))

    
model_xgb = GradientBoostingRegressor(n_estimators=xgb_grid.best_params_['n_estimators']).fit(xtrain, ytrain)

true_pred_plot(ytrain, model_xgb.predict(xtrain), ytest, model_xgb.predict(xtest),'xgb_ergy.png')
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best params on training set : {'n_estimators': 500}
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# E:\Data_Science\Anaconda\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
def r2(pred,y):
    pred = np.array(pred).reshape(-1,1)
    y = np.array(y).reshape(-1,1)
    
    pred = pred*sqftest
    y = y*sqftest
    
    line_reg_test  = line_reg.fit(pred,y)
    r2_value =  line_reg_test.score(pred,y)
    return r2_value

def rmse(pred,y):
    pred = np.array(pred).reshape(-1,1)
    y = np.array(y).reshape(-1,1)
    
    pred = pred*sqftest
    y = y*sqftest
    
    rmse_value = np.sqrt(metrics.mean_squared_error(y,pred))
    return rmse_value

def nrmse(pred,y):
    pred = np.array(pred).reshape(-1,1)
    y = np.array(y).reshape(-1,1)
    
    pred = pred*sqftest
    y = y*sqftest
    
    nrmse_value = (np.sqrt(metrics.mean_squared_error(y,pred))/np.mean(y))
    return nrmse_value
                   
def mae(pred,y):
    pred = np.array(pred).reshape(-1,1)
    y = np.array(y).reshape(-1,1)
    
    pred = pred*sqftest
    y = y*sqftest
    
    mae_value = metrics.mean_absolute_error(y,pred)
    return mae_value

# %%
metrics_all = {}

models = [model_kn,svr,model_krr,model1,model3,model_rfr,model_xgb]
r2l=[]
rmsel=[]
nrmsel=[]
mael=[]

for i in models:
    r2l.append(r2(i.predict(xtest),ytest))
    rmsel.append(rmse(i.predict(xtest), ytest))
    nrmsel.append(nrmse(i.predict(xtest), ytest))
    mael.append(mae(i.predict(xtest), ytest))
    
metrics_all['r2'] = r2l
metrics_all['rmse'] = rmsel
metrics_all['nrmse'] = nrmsel
metrics_all['mae'] = mael

model_names = ['KNN_Regressor', 'SVR', 'Kernel_Ridge_Regressor','Perceptron','Neural_Network', 'Random_Forest_Regressor', 'XGBoost']
df_metrics = pd.DataFrame(metrics_all, index = model_names)

fig = plt.figure(figsize=(27, 18))
for i in range(df_metrics.shape[1]):
    ax = fig.add_subplot(2,2, (i+1))
    b = ax.bar(x=df_metrics.index,height = df_metrics.iloc[:, i])
    for y,v in enumerate(df_metrics.iloc[:, i]):
        ax.text(y,v, '%.2f'%v, ha = 'center')
    ax.set_title(df_metrics.columns[i], fontsize=14)
    ax.tick_params(axis='x', labelrotation = 35)
    if i != 0:
        ax.set_yscale('log')
plt.savefig('recap_ergy.png', bbox_inches = 'tight')
# Out:
# 11/11 [==============================] - 0s 800us/step
# 11/11 [==============================] - 0s 1000us/step
# 11/11 [==============================] - 0s 700us/step
# 11/11 [==============================] - 0s 800us/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 450 out of 450 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 450 out of 450 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 450 out of 450 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 450 out of 450 | elapsed:    0.0s finished

# %%
importance = model_xgb.feature_importances_
nul_col = []
for i,v in enumerate(importance):
    if v == 0:
        nul_col.append(i)
nul_col_name = []
for i in nul_col:
    nul_col_name.append(col_name_lib[str(i)])
print(len(nul_col_name))

df_fi = {}
for i,v in enumerate(importance):
    x = col_name_lib[str(i)]
    df_fi[f'{x}'] = v

df_fi = pd.DataFrame(df_fi, index = ['Feature_Importance']).T
print(df_fi['Feature_Importance'].nlargest(10))


# plot feature importance
fig, ax = plt.subplots(figsize = (20,20))
ax.bar([x for x in range(len(importance))], importance)
plt.show()
plt.savefig('feat_imp_ergy.png', bbox_inches = 'tight')
# Out:
# 281
# ThirdLargestPropertyUseTypeGFA                       0.260011
# LargestPropertyUseType_Non-Refrigerated Warehouse    0.094024
# PropertyGFABuilding(s)                               0.082007
# LargestPropertyUseType_Self-Storage Facility         0.055028
# LargestPropertyUseType_Supermarket/Grocery Store     0.054156
# SecondLargestPropertyUseTypeGFA                      0.050394
# YearBuilt                                            0.024007
# LargestPropertyUseType_Distribution Center           0.022679
# PrimaryPropertyType_Other                            0.019434
# Latitude                                             0.018559
# Name: Feature_Importance, dtype: float64

# %%
df_year={}
df_tar = pd.DataFrame(ytest)
df_res = df_res.join(df_tar)
for i in df_res['YearBuilt'].unique():
    df_year[f'{i}'] = df_res[df_res['YearBuilt'] == i]
len(df_year)
# Out:
# 96

# %%
df_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 326 entries, 823 to 942
# Columns: 523 entries, BuildingType_Campus to SiteEUI(kBtu/sf)
# dtypes: float64(523)
# memory usage: 1.3 MB

# %%
def feature_error(df_lib,model,met,newcol=None):
    results = []
    for i in df_lib:
        x = df_lib[str(i)]
        if newcol:
            x = x.drop(axis = 1, labels = newcol)
        y = x['SiteEUI(kBtu/sf)']
        x = x.drop(axis = 1, labels = 'SiteEUI(kBtu/sf)')
        sqf = x['PropertyGFABuilding(s)']
        x = sscaler_fit.transform(x)
        
        y = np.array(np.log(y)).reshape(-1,1)     
        pred = model.predict(x)
        
        y = np.array(y).reshape(-1,1)
        pred = np.array(pred).reshape(-1,1)
        
        sqf = np.array(sqf).reshape(-1,1)
        y = y*sqf
        pred = pred*sqf
        
        if met == 'r2':
            line_reg_fit  = line_reg.fit(pred,y)
            results.append(line_reg_fit.score(pred,y))
        if met == 'nrmse':
            results.append(np.sqrt(metrics.mean_squared_error(y,pred))/np.mean(y))
        if met =='mae':
            results.append(np.sqrt(metrics.mean_absolute_error(y,pred)))
        
    return results

# %%
results = feature_error(df_year,model_xgb,'mae')

results_year = {}
for i,v in zip(df_year,results):
    results_year[f'{i}'] = v
    
results_year = pd.DataFrame(results_year, index = ['NRMSE']).T
print(results_year['NRMSE'].nlargest(10))

fig, ax = plt.subplots(1,2,figsize = (30,15))
ax[0].bar([x for x in range(len(results_year.index))],results_year['NRMSE'])
ax[0].text(0.7,0.4,'mean : {:.3f} max : {: .2f}'.format(results_year['NRMSE'].mean(), results_year['NRMSE'].max()), transform = ax[0].transAxes)
ax[1].pie(df_res_train['YearBuilt'].value_counts(), labels = df_res_train['YearBuilt'].unique())
plt.savefig('YearBuilt_ergy.png', bbox_inches = 'tight')
plt.show()
# Out:
# 1981.0    1159.589430
# 1929.0     987.899540
# 1912.0     981.585012
# 1953.0     965.000438
# 1999.0     942.635484
# 2015.0     866.203809
# 1916.0     858.198907
# 1938.0     842.521278
# 2000.0     795.721474
# 2008.0     762.146275
# Name: NRMSE, dtype: float64

# %%
df_gfa = df
df_gfa['GFAdistribution'] = pd.qcut(df_gfa['ThirdLargestPropertyUseTypeGFA'],10, duplicates = 'drop')
target = df_gfa[target_tag]
sqf = df_gfa['PropertyGFABuilding(s)']
gfa_dis = df_gfa['GFAdistribution']
df_gfa = df_gfa.drop(labels = [target_tag,'GFAdistribution', 'TotalGHGEmissions', 'ENERGYSTARScore','SiteEnergyUse(kBtu)', 'GHGEmissionsIntensity'], axis = 1)

xtrain, xtest, ytrain, ytest, sqftrain, sqftest, distrain, distest = train_test_split(df_gfa, target, sqf, gfa_dis, test_size = 0.2, random_state = rand)
df_gfa_res = xtest
df_gfa_res = df_gfa_res.join(pd.DataFrame(distest))
df_gfa_res = df_gfa_res.join(pd.DataFrame(ytest))


df_gfa_lib = {}
for i,v in enumerate(df_gfa_res['GFAdistribution'].unique()):
    df_gfa_lib[f'{i}'] = df_gfa_res[df_gfa_res['GFAdistribution'] == v]

results = feature_error(df_gfa_lib,model_xgb,'mae',newcol = 'GFAdistribution')

results_gfa = {}
for i,v in zip(df_gfa_lib,results):
    results_gfa[f'{str(i)}'] = v
    
results_gfa = pd.DataFrame(results_gfa, index = ['NRMSE']).T
print(results_gfa['NRMSE'].nlargest(10))

fig, ax = plt.subplots(figsize = (15,15))
ax.bar([x for x in range(len(results_gfa.index))],results_gfa['NRMSE'])
ax.text(0.7,0.4,'mean : {:.3f} max : {: .2f}'.format(results_gfa['NRMSE'].mean(), results_gfa['NRMSE'].max()), transform = ax.transAxes)
plt.savefig('ThirdGFAanalysis.png', bbox_inches = 'tight')
plt.show()
# Out:
# 8    386.457582
# 1    255.938065
# 3    222.698012
# 9    210.035913
# 0    169.870911
# 4    144.469267
# 6    129.194624
# 5    128.348068
# 7    125.529910
# 2    118.407051
# Name: NRMSE, dtype: float64

# %%
df_tar = df
df_tar['Ydistribution'] = pd.qcut(df_tar[target_tag],10, duplicates = 'drop')
target = df_tar[target_tag]
sqf = df_tar['PropertyGFABuilding(s)']
dis = df_tar['Ydistribution']
df_tar = df_tar.drop(labels = [target_tag,'Ydistribution','TotalGHGEmissions', 'ENERGYSTARScore','SiteEnergyUse(kBtu)', 'GHGEmissionsIntensity'], axis = 1)

xtrain, xtest, ytrain, ytest, sqftrain, sqftest,distrain,distest = train_test_split(df_gfa, target, sqf,dis, test_size = 0.2, random_state = rand)
df_tar_res = xtest
df_tar_res = df_tar_res.join(pd.DataFrame(dis))
df_tar_res = df_tar_res.join(pd.DataFrame(ytest))


df_tar_lib = {}
for i,v in enumerate(df_tar_res['Ydistribution'].unique()):
    df_tar_lib[f'{i}'] = df_tar_res[df_tar_res['Ydistribution'] == v]

results = feature_error(df_tar_lib,model_xgb,'mae',newcol = 'Ydistribution')

results_tar = {}
for i,v in zip(df_tar_lib,results):
    results_tar[f'{str(i)}'] = v
    
results_tar = pd.DataFrame(results_tar, index = ['NRMSE']).T
print(results_tar['NRMSE'].nlargest(10))

fig, ax = plt.subplots(figsize = (15,15))
ax.bar([x for x in range(len(results_tar.index))],results_tar['NRMSE'])
ax.text(0.7,0.4,'mean : {:.3f} max : {: .2f}'.format(results_tar['NRMSE'].mean(), results_tar['NRMSE'].max()), transform = ax.transAxes)
plt.savefig('TargetAanalysis.png', bbox_inches = 'tight')
plt.show()
# Out:
# 5    281.694377
# 1    242.614958
# 6    221.700683
# 4    194.995290
# 7    193.592801
# 0    191.835210
# 2    189.366776
# 3    178.670894
# 8    165.883494
# 9    153.087094
# Name: NRMSE, dtype: float64

# %% [markdown]
# ### Etude de l'impact de l'Energy Score

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1630 entries, 0 to 1629
# Columns: 529 entries, BuildingType_Campus to Ydistribution
# dtypes: category(2), float64(527)
# memory usage: 6.6 MB

# %%
data_num = df
target_tag = 'SiteEUI(kBtu/sf)'
target = data_num[target_tag]
label = ['TotalGHGEmissions', 'SiteEnergyUse(kBtu)', 'GHGEmissionsIntensity']
sqf = data_num['PropertyGFABuilding(s)']
data_num = data_num.drop(labels = [target_tag, 'TotalGHGEmissions','SiteEnergyUse(kBtu)', 'GHGEmissionsIntensity'], axis = 1)

col_name_lib = {}
col_name = data_num.columns
for i,v in enumerate(col_name):
    col_name_lib[f'{i}'] = v

#first let's test this on knregressoe
xtrain, xtest, ytrain, ytest, sqftrain, sqftest = train_test_split(data_num, target, sqf, test_size = 0.2)

df_res = xtrain

#let's standard scale

sscaler = sk_prepro.StandardScaler()
sscaler_fit = sscaler.fit(xtrain)
xtrain = sscaler_fit.transform(xtrain)
xtest = sscaler_fit.transform(xtest)
#log scale the target
ytrain = np.log(ytrain)
ytest = np.log(ytest)

sqftrain = np.array(sqftrain).reshape(-1,1)
sqftest = np.array(sqftest).reshape(-1,1)

# %%
#let's grid search for the k

k_grid = {'n_neighbors' : list(range(2,16))}
score = 'r2'

reg = GridSearchCV(KNeighborsRegressor(), k_grid, cv =3, scoring = score, verbose = 1)

reg.fit(xtrain, ytrain)
    
model_kn2 = KNeighborsRegressor(n_neighbors = reg.best_params_['n_neighbors']).fit(xtrain, ytrain)

 #let's try with a svr
C_range = [1.0, 5.0, 10.0, 100.0]
kernels = ['linear', 'rbf', 'sigmoid', 'poly']
degrees = [2,3,4]
gamma_range  = np.logspace(-2, 1, 10)

param_grid = {'gamma' : gamma_range, 'kernel' : kernels, 'degree' : degrees}

score = 'neg_mean_squared_error'

svr_cv = GridSearchCV(svm.SVR(), param_grid, cv = 3, scoring = score, verbose = 1)

svr_cv.fit(xtrain, ytrain)


bkernel = svr_cv.best_params_['kernel']
bgamma = svr_cv.best_params_['gamma']
bdegree = svr_cv.best_params_['degree']
    
svr = svm.SVR(kernel=bkernel, C=1.0, gamma = bgamma, degree = bdegree)
model_svr2 = svr.fit(xtrain,ytrain)


#kernel ridge
alpha_range = [1.0, 5.0, 10.0, 100.0]
kernels = ['linear', 'poly', 'rbf']
degrees = [3,4,5]
gamma_range  = np.logspace(-2, 1, 10)


param_grid = {'gamma' : gamma_range, 'kernel' : kernels, 'degree' : degrees, 'alpha' : alpha_range}
    
score = 'neg_mean_absolute_percentage_error'

kernel_ridge_cv = GridSearchCV(kernel_ridge.KernelRidge(), param_grid, cv = 3, scoring = score, verbose = 1)

kernel_ridge_cv.fit(xtrain, ytrain)
    
bkernel = kernel_ridge_cv.best_params_['kernel']
bgamma = kernel_ridge_cv.best_params_['gamma']
bdegree = kernel_ridge_cv.best_params_['degree']
balpha = kernel_ridge_cv.best_params_['alpha']

model = kernel_ridge.KernelRidge(alpha = balpha, kernel = bkernel, degree = bdegree, gamma = bgamma)
model_krr2 = model.fit(xtrain, ytrain)

#test with a single perceptron
model1_2 = keras.Sequential()
model1_2.add(keras.Input(shape = xtrain.shape[1]))
model1_2.add(layers.Dense(1,input_dim = 2, activation = 'linear'))

model1_2.compile(metrics = [tf.keras.metrics.RootMeanSquaredError()], loss = 'mean_absolute_percentage_error', optimizer = 'adam')

model1_2.summary()

history1 = model1_2.fit(xtrain, ytrain, epochs = 50, batch_size = 1, verbose = 1)

# neural network

model3_2 = keras.Sequential(
    [
        layers.Dense(xtrain.shape[1], activation="selu", name="layer1", input_shape=(xtrain.shape[1],), input_dim = 2),
        layers.Dense(383, activation="selu", name="layer2a"),
        layers.Dense(287, activation="selu", name="layer2"),
        layers.Dense(82, activation="selu", name="layer3"),
        layers.Dense(20, activation="selu", name="layer4"),
        layers.Dense(1, activation = 'linear', name="layer6"),
    ]
)

model3_2.compile(metrics = [tf.keras.metrics.RootMeanSquaredError()], loss = 'mean_absolute_percentage_error', optimizer = 'adam')

model3_2.summary()

history3 = model3_2.fit(xtrain, ytrain, epochs = 50, batch_size = 1, verbose = 1)

#random forest

n_grid = {'n_estimators' : list(np.arange(50,550,50))}
score = 'r2'

rfr_grid = GridSearchCV(RandomForestRegressor(), n_grid, cv =3, scoring = score, verbose = 1)

rfr_grid.fit(xtrain, ytrain)
    
model_rfr2 = RandomForestRegressor(n_estimators=rfr_grid.best_params_['n_estimators'], verbose = 1).fit(xtrain, ytrain)

#xgBoost

n_grid = {'n_estimators' : list(np.arange(50,550,50))}
score = 'r2'

xgb_grid = GridSearchCV(GradientBoostingRegressor(), n_grid, cv =3, scoring = score, verbose = 1)

xgb_grid.fit(xtrain, ytrain)
    
model_xgb2 = GradientBoostingRegressor(n_estimators=xgb_grid.best_params_['n_estimators']).fit(xtrain, ytrain)
# Out:
# Fitting 3 folds for each of 14 candidates, totalling 42 fits
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# Fitting 3 folds for each of 360 candidates, totalling 1080 fits
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 524
#
# =================================================================
# Total params: 524
# Trainable params: 524
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1304/1304 [==============================] - 2s 917us/step - loss: 116.1727 - root_mean_squared_error: 8.1537
# Epoch 2/50
# 1304/1304 [==============================] - 1s 991us/step - loss: 88.4996 - root_mean_squared_error: 7.1472
# Epoch 3/50
# 1304/1304 [==============================] - 1s 880us/step - loss: 77.6777 - root_mean_squared_error: 6.5300
# Epoch 4/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 68.4481 - root_mean_squared_error: 5.9581
# Epoch 5/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 60.5427 - root_mean_squared_error: 5.3952
# Epoch 6/50
# 1304/1304 [==============================] - 1s 899us/step - loss: 53.4385 - root_mean_squared_error: 4.8989
# Epoch 7/50
# 1304/1304 [==============================] - 1s 948us/step - loss: 47.4285 - root_mean_squared_error: 4.4257
# Epoch 8/50
# 1304/1304 [==============================] - 1s 891us/step - loss: 42.2756 - root_mean_squared_error: 3.9924
# Epoch 9/50
# 1304/1304 [==============================] - 1s 903us/step - loss: 37.6312 - root_mean_squared_error: 3.6020
# Epoch 10/50
# 1304/1304 [==============================] - 1s 891us/step - loss: 33.7614 - root_mean_squared_error: 3.2289
# Epoch 11/50
# 1304/1304 [==============================] - 1s 889us/step - loss: 30.3496 - root_mean_squared_error: 2.8748
# Epoch 12/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 27.1342 - root_mean_squared_error: 2.5639
# Epoch 13/50
# 1304/1304 [==============================] - 1s 994us/step - loss: 24.6881 - root_mean_squared_error: 2.2575
# Epoch 14/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 22.1731 - root_mean_squared_error: 1.9729
# Epoch 15/50
# 1304/1304 [==============================] - 1s 921us/step - loss: 20.0143 - root_mean_squared_error: 1.7327
# Epoch 16/50
# 1304/1304 [==============================] - 1s 946us/step - loss: 18.3416 - root_mean_squared_error: 1.5030
# Epoch 17/50
# 1304/1304 [==============================] - 1s 976us/step - loss: 16.3482 - root_mean_squared_error: 1.2719
# Epoch 18/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 15.4600 - root_mean_squared_error: 1.1000
# Epoch 19/50
# 1304/1304 [==============================] - 1s 893us/step - loss: 14.3269 - root_mean_squared_error: 0.9521
# Epoch 20/50
# 1304/1304 [==============================] - 1s 936us/step - loss: 13.6743 - root_mean_squared_error: 0.8306
# Epoch 21/50
# 1304/1304 [==============================] - 1s 1000us/step - loss: 13.1588 - root_mean_squared_error: 0.7419
# Epoch 22/50
# 1304/1304 [==============================] - 1s 1ms/step - loss: 12.6086 - root_mean_squared_error: 0.6710
# Epoch 23/50
# 1304/1304 [==============================] - 1s 1000us/step - loss: 12.3044 - root_mean_squared_error: 0.6320
# Epoch 24/50
# 1304/1304 [==============================] - 1s 890us/step - loss: 12.3372 - root_mean_squared_error: 0.6148
# Epoch 25/50
# 1304/1304 [==============================] - 1s 952us/step - loss: 12.2276 - root_mean_squared_error: 0.6187
# Epoch 26/50
# 1304/1304 [==============================] - 1s 922us/step - loss: 12.1672 - root_mean_squared_error: 0.6097
# Epoch 27/50
# 1304/1304 [==============================] - 1s 869us/step - loss: 12.1294 - root_mean_squared_error: 0.6098
# Epoch 28/50
# 1304/1304 [==============================] - 1s 853us/step - loss: 12.0868 - root_mean_squared_error: 0.6081
# Epoch 29/50
# 1304/1304 [==============================] - 1s 893us/step - loss: 12.1570 - root_mean_squared_error: 0.6164
# Epoch 30/50
# 1304/1304 [==============================] - 1s 903us/step - loss: 12.0170 - root_mean_squared_error: 0.6035
# Epoch 31/50
# 1304/1304 [==============================] - 1s 915us/step - loss: 12.1366 - root_mean_squared_error: 0.6026
# Epoch 32/50
# 1304/1304 [==============================] - 1s 886us/step - loss: 11.8347 - root_mean_squared_error: 0.5953
# Epoch 33/50
# 1304/1304 [==============================] - 1s 903us/step - loss: 12.1856 - root_mean_squared_error: 0.6035
# Epoch 34/50
# 1304/1304 [==============================] - 1s 863us/step - loss: 12.0886 - root_mean_squared_error: 0.6078
# Epoch 35/50
# 1304/1304 [==============================] - 1s 983us/step - loss: 12.2318 - root_mean_squared_error: 0.6177
# Epoch 36/50
# 1304/1304 [==============================] - 1s 965us/step - loss: 11.8332 - root_mean_squared_error: 0.5993
# Epoch 37/50
# 1304/1304 [==============================] - 1s 869us/step - loss: 12.1332 - root_mean_squared_error: 0.6064
# Epoch 38/50
# 1304/1304 [==============================] - 1s 851us/step - loss: 11.9061 - root_mean_squared_error: 0.6003
# Epoch 39/50
# 1304/1304 [==============================] - 1s 886us/step - loss: 12.0661 - root_mean_squared_error: 0.6103
# Epoch 40/50
# 1304/1304 [==============================] - 1s 881us/step - loss: 11.9502 - root_mean_squared_error: 0.5947
# Epoch 41/50
# 1304/1304 [==============================] - 1s 880us/step - loss: 12.0101 - root_mean_squared_error: 0.6115
# Epoch 42/50
# 1304/1304 [==============================] - 1s 878us/step - loss: 12.1436 - root_mean_squared_error: 0.6055
# Epoch 43/50
# 1304/1304 [==============================] - 1s 883us/step - loss: 12.0281 - root_mean_squared_error: 0.5964
# Epoch 44/50
# 1304/1304 [==============================] - 1s 942us/step - loss: 11.9218 - root_mean_squared_error: 0.5899
# Epoch 45/50
# 1304/1304 [==============================] - 1s 862us/step - loss: 12.0752 - root_mean_squared_error: 0.6051
# Epoch 46/50
# 1304/1304 [==============================] - 1s 859us/step - loss: 11.8708 - root_mean_squared_error: 0.5959
# Epoch 47/50
# 1304/1304 [==============================] - 1s 861us/step - loss: 12.0042 - root_mean_squared_error: 0.5947
# Epoch 48/50
# 1304/1304 [==============================] - 1s 859us/step - loss: 11.8355 - root_mean_squared_error: 0.5892
# Epoch 49/50
# 1304/1304 [==============================] - 1s 852us/step - loss: 11.9925 - root_mean_squared_error: 0.6037
# Epoch 50/50
# 1304/1304 [==============================] - 1s 872us/step - loss: 11.7318 - root_mean_squared_error: 0.5902
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 523)               274052
#
#  layer2a (Dense)             (None, 383)               200692
#
#  layer2 (Dense)              (None, 287)               110208
#
#  layer3 (Dense)              (None, 82)                23616
#
#  layer4 (Dense)              (None, 20)                1660
#
#  layer6 (Dense)              (None, 1)                 21
#
# =================================================================
# Total params: 610,249
# Trainable params: 610,249
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1304/1304 [==============================] - 4s 2ms/step - loss: 38.8501 - root_mean_squared_error: 2.3974
# Epoch 2/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 25.9152 - root_mean_squared_error: 1.4576
# Epoch 3/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 17.7965 - root_mean_squared_error: 0.9203
# Epoch 4/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 16.3556 - root_mean_squared_error: 0.8405
# Epoch 5/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 15.6689 - root_mean_squared_error: 0.7700
# Epoch 6/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 13.8456 - root_mean_squared_error: 0.6753
# Epoch 7/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 12.8999 - root_mean_squared_error: 0.6231
# Epoch 8/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 13.6055 - root_mean_squared_error: 0.9673
# Epoch 9/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.8117 - root_mean_squared_error: 0.5564
# Epoch 10/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 11.2647 - root_mean_squared_error: 0.5448
# Epoch 11/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 11.1515 - root_mean_squared_error: 0.5411
# Epoch 12/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 12.4308 - root_mean_squared_error: 0.8076
# Epoch 13/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 13.0483 - root_mean_squared_error: 2.4324
# Epoch 14/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 13.0582 - root_mean_squared_error: 1.9758
# Epoch 15/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 10.4811 - root_mean_squared_error: 0.5562
# Epoch 16/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 11.9310 - root_mean_squared_error: 1.5900
# Epoch 17/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 9.4969 - root_mean_squared_error: 0.5260
# Epoch 18/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 9.5895 - root_mean_squared_error: 0.4606
# Epoch 19/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 22.8390 - root_mean_squared_error: 13.7955
# Epoch 20/50
# 1304/1304 [==============================] - 3s 2ms/step - loss: 13.3980 - root_mean_squared_error: 4.9491
# Epoch 21/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 9.0089 - root_mean_squared_error: 0.4435
# Epoch 22/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 9.7236 - root_mean_squared_error: 0.5885
# Epoch 23/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 69.2541 - root_mean_squared_error: 72.2434
# Epoch 24/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 8.7014 - root_mean_squared_error: 0.4305
# Epoch 25/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 9.4354 - root_mean_squared_error: 0.8432
# Epoch 26/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 8.8538 - root_mean_squared_error: 0.4373
# Epoch 27/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 8.8029 - root_mean_squared_error: 0.4316
# Epoch 28/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 8.7102 - root_mean_squared_error: 0.4308
# Epoch 29/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 9.3080 - root_mean_squared_error: 0.4495
# Epoch 30/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 9.3320 - root_mean_squared_error: 0.6851
# Epoch 31/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 9.3772 - root_mean_squared_error: 0.6997
# Epoch 32/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 10.7567 - root_mean_squared_error: 2.8592
# Epoch 33/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 8.6186 - root_mean_squared_error: 0.4484
# Epoch 34/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 34.4259 - root_mean_squared_error: 38.1028
# Epoch 35/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 7.5568 - root_mean_squared_error: 0.3846
# Epoch 36/50
# 1304/1304 [==============================] - 4s 3ms/step - loss: 7.6002 - root_mean_squared_error: 0.3949
# Epoch 37/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 7.6919 - root_mean_squared_error: 0.3867
# Epoch 38/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 7.9906 - root_mean_squared_error: 0.3924
# Epoch 39/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 8.4121 - root_mean_squared_error: 0.4873
# Epoch 40/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 7.6680 - root_mean_squared_error: 0.3813
# Epoch 41/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 8.0840 - root_mean_squared_error: 0.5399
# Epoch 42/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 7.6731 - root_mean_squared_error: 0.3851
# Epoch 43/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 7.6720 - root_mean_squared_error: 0.3884
# Epoch 44/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 7.7617 - root_mean_squared_error: 0.3895
# Epoch 45/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 10.5594 - root_mean_squared_error: 2.1606
# Epoch 46/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 72.1327 - root_mean_squared_error: 34.0626
# Epoch 47/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 7.2410 - root_mean_squared_error: 0.3717
# Epoch 48/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 13.6583 - root_mean_squared_error: 9.1153
# Epoch 49/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 6.8909 - root_mean_squared_error: 0.3606
# Epoch 50/50
# 1304/1304 [==============================] - 3s 3ms/step - loss: 6.9718 - root_mean_squared_error: 0.3505
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:    7.4s finished
# Fitting 3 folds for each of 10 candidates, totalling 30 fits

# %%
#plot the metrics

metrics_all = {}

models = [model_kn2,model_svr2,model_krr2,model1_2,model3_2,model_rfr2,model_xgb2]
r2l=[]
rmsel=[]
nrmsel=[]
mael=[]

for i in models:
    r2l.append(r2(i.predict(xtest),ytest))
    rmsel.append(rmse(i.predict(xtest), ytest))
    nrmsel.append(nrmse(i.predict(xtest), ytest))
    mael.append(mae(i.predict(xtest), ytest))
    
metrics_all['r2'] = r2l
metrics_all['rmse'] = rmsel
metrics_all['nrmse'] = nrmsel
metrics_all['mae'] = mael

model_names = ['KNN_Regressor', 'SVR', 'Kernel_Ridge_Regressor','Perceptron','Neural_Network', 'Random_Forest_Regressor', 'XGBoost']
df_metrics = pd.DataFrame(metrics_all, index = model_names)

fig = plt.figure(figsize=(20, 20))
for i in range(df_metrics.shape[1]):
    ax = fig.add_subplot(2,2, (i+1))
    b = ax.bar(x=df_metrics.index,height = df_metrics.iloc[:, i])
    for y,v in enumerate(df_metrics.iloc[:, i]):
        ax.text(y,v, '%.2f'%v, ha = 'center')
    ax.set_title(df_metrics.columns[i], fontsize=14)
    ax.tick_params(axis='x', labelrotation = 35)
    if i != 0:
        ax.set_yscale('log')
        
plt.savefig('recap_ergy_ess.png', bbox_inches = 'tight')
# Out:
# 11/11 [==============================] - 0s 900us/step
# 11/11 [==============================] - 0s 700us/step
# 11/11 [==============================] - 0s 700us/step
# 11/11 [==============================] - 0s 800us/step
# 11/11 [==============================] - 0s 3ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:    0.0s finished

# %%
importance = model_xgb2.feature_importances_
nul_col = []
for i,v in enumerate(importance):
    if v == 0:
        nul_col.append(i)
nul_col_name = []
for i in nul_col:
    nul_col_name.append(col_name_lib[str(i)])
print(len(nul_col_name))

df_fi = {}
for i,v in enumerate(importance):
    x = col_name_lib[str(i)]
    df_fi[f'{x}'] = v

df_fi = pd.DataFrame(df_fi, index = ['Feature_Importance']).T
print(df_fi['Feature_Importance'].nlargest(10))


# plot feature importance
fig, ax = plt.subplots(figsize = (20,20))
ax.bar([x for x in range(len(importance))], importance)
plt.show()
plt.savefig('feat_imp_ergy_ess.png', bbox_inches = 'tight')
# Out:
# 301
# ENERGYSTARScore                                            0.286281
# ThirdLargestPropertyUseTypeGFA                             0.129027
# LargestPropertyUseType_Non-Refrigerated Warehouse          0.114475
# SecondLargestPropertyUseTypeGFA                            0.062771
# LargestPropertyUseType_Supermarket/Grocery Store           0.036003
# LargestPropertyUseType_Distribution Center                 0.034945
# PropertyGFABuilding(s)                                     0.027643
# LargestPropertyUseType_Self-Storage Facility               0.027086
# SecondLargestPropertyUseType_Non-Refrigerated Warehouse    0.022850
# LargestPropertyUseType_Data Center                         0.017808
# Name: Feature_Importance, dtype: float64
